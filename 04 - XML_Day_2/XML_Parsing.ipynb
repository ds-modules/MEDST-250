# %% [markdown]
# # [MEDST-250] Text Analysis for Medievalists
# In this Jupyter notebook, we will look to see how to analyze and parse text from an XML file. We will be looking at two different modules in Python that make it easy for us to parse through XML files. These modules will be the ElementTree module and the lxml module. Both the commands for both API's are quite similar, as you are dealing with the tree structure of XML (will be discussed later), so it is purely up to you to choose how you wish to deal with this.
#
# ### Topics Covered
# - Using ElementTree module (Method 1)
# - Using lxml Module (Method 2)
#
# ### Table of Contents
#
# [The Data](#section data)<br>
#
#
# 1 - [Section 1: Parsing XML using ElementTree](#section 1)<br>
#
# 2 - [Section 2: Parsing XML using lxml](#section 2)<br>
#
#
#
#
# **Dependencies:**

# %%
import xml.etree.cElementTree as ET
from lxml import etree
## No need to worry about this, this simply imports the modules, ElementTree and lxml, that allows us to parse the XML file.

# %% [markdown]
# ---
#
# ## The Data <a id='data'></a>
# In this notebook, you'll be working with a XML file from Piers Plowman. An XML file is a basic markup of content in a file that gathers and contains a certain amount of material within different tags and subtags. We will be using this XML file to learn in general how to parse XML files of Medieval Texts The texts come from http://piers.chass.ncsu.edu/texts.html. From now on, we will be using an example in the data folder called "ppexample.xml" as our test for parsing through.
#
# ---

# %% [markdown]
# ## Section 1 Parsing XML File using cElementTree Module  <a id='section 1'></a>

# %% [markdown]
# First we need to import the XML file into an ElementTree instance, this basically creates a ElementTree format of all this subtags of each tag in the XML file so we can further analyze the file.

# %%
xml_file = 'data/ppexample.xml'
tree = ET.ElementTree(file=xml_file)
root = tree.getroot()
print(tree.getroot())
# Out:
# <Element 'TEI.2' at 0x109239f48>

# %% [markdown]
# We then find all the child tags and roots and print them out so we can view them for better viewing in the future. An XML file has a root file that has children, and each of these children has a tag and attribute, as well as some associated text with it.

# %%
for child in root:
    print(child.tag, child.attrib)
    for step_child in child:
        print("Step Child Tag: " + step_child.tag)
        for child in step_child:
            
            print("Children of this: " + child.tag)
# Out:
# teiHeader {}
# Step Child Tag: fileDesc
# Children of this: titleStmt
# Children of this: publicationStmt
# Children of this: seriesStmt
# Children of this: sourceDesc
# Step Child Tag: encodingDesc
# Children of this: editorialDecl
# Step Child Tag: profileDesc
# Children of this: langUsage
# Children of this: handList
# Children of this: textClass
# Step Child Tag: revisionDesc
# Children of this: change
# text {}
# Step Child Tag: front
# Step Child Tag: body
# Children of this: div1

# %% [markdown]
# Now we can see each child tag and it's step child tags that come from it. This is where the "Tree" hierarchy of each element tag comes in, each tag has it's own sub/step childs that branch off of it.
#
# To fully grasp this ideology, we can iterate through all the elements in the XML file by creating an iterator (something that goes through all parts of a file) and iterating through all possible elements/their tags

# %%
iter_ = tree.getiterator()
for elem in iter_:
    print("Element tag: " + elem.tag)
# Out:
# Element tag: TEI.2
# Element tag: teiHeader
# Element tag: fileDesc
# Element tag: titleStmt
# Element tag: title
# Element tag: author
# Element tag: editor
# Element tag: editor
# Element tag: respStmt
# Element tag: resp
# Element tag: hi
# Element tag: name
# Element tag: respStmt
# Element tag: resp
# Element tag: hi
# Element tag: name
# Element tag: publicationStmt
# Element tag: publisher
# Element tag: pubPlace
# Element tag: idno
# Element tag: availability
# Element tag: p
# Element tag: p
# Element tag: date
# Element tag: seriesStmt
# Element tag: p
# Element tag: sourceDesc
# Element tag: biblFull
# Element tag: titleStmt
# Element tag: title
# Element tag: editionStmt
# Element tag: p
# Element tag: extent
# Element tag: publicationStmt
# Element tag: publisher
# Element tag: pubPlace
# Element tag: date
# Element tag: idno
# Element tag: encodingDesc
# Element tag: editorialDecl
# Element tag: p
# Element tag: list
# Element tag: head
# Element tag: item
# Element tag: label
# Element tag: term
# Element tag: item
# Element tag: label
# Element tag: term
# Element tag: item
# Element tag: label
# Element tag: term
# Element tag: item
# Element tag: label
# Element tag: term
# Element tag: item
# Element tag: label
# Element tag: term
# Element tag: item
# Element tag: label
# Element tag: term
# Element tag: item
# Element tag: label
# Element tag: term
# Element tag: item
# Element tag: label
# Element tag: term
# Element tag: item
# Element tag: label
# Element tag: term
# Element tag: item
# Element tag: label
# Element tag: term
# Element tag: item
# Element tag: label
# Element tag: term
# Element tag: item
# Element tag: label
# Element tag: term
# Element tag: profileDesc
# Element tag: langUsage
# Element tag: language
# Element tag: language
# Element tag: language
# Element tag: handList
# Element tag: hand
# Element tag: hand
# Element tag: hand
# Element tag: textClass
# Element tag: keywords
# Element tag: term
# Element tag: term
# Element tag: revisionDesc
# Element tag: change
# Element tag: date
# Element tag: respStmt
# Element tag: resp
# Element tag: name
# Element tag: item
# Element tag: text
# Element tag: front
# Element tag: body
# Element tag: div1
# Element tag: head
# Element tag: milestone
# Element tag: note
# Element tag: milestone
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: orig
# Element tag: reg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: milestone
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: sic
# Element tag: expan
# Element tag: corr
# Element tag: note
# Element tag: ref
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: seg
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: sic
# Element tag: corr
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: title
# Element tag: seg
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: milestone
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: sic
# Element tag: corr
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: lb
# Element tag: lb
# Element tag: lb
# Element tag: lb
# Element tag: lb
# Element tag: lb
# Element tag: lb
# Element tag: lb
# Element tag: lb
# Element tag: lb
# Element tag: lb
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: sic
# Element tag: corr
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: lb
# Element tag: lb
# Element tag: lb
# Element tag: lb
# Element tag: lb
# Element tag: l
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: sic
# Element tag: corr
# Element tag: note
# Element tag: ref
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: sic
# Element tag: corr
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: sic
# Element tag: expan
# Element tag: corr
# Element tag: l
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: seg
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: milestone
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: sic
# Element tag: hi
# Element tag: hi
# Element tag: corr
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: sic
# Element tag: corr
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: title
# Element tag: title
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: seg
# Element tag: milestone
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: add
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: lb
# Element tag: lb
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: seg
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: expan
# Element tag: add
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: sic
# Element tag: corr
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: lb
# Element tag: lb
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: sic
# Element tag: corr
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: milestone
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: l
# Element tag: sic
# Element tag: hi
# Element tag: corr
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: sic
# Element tag: corr
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: seg
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: milestone
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: hi
# Element tag: l
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: sic
# Element tag: expan
# Element tag: corr
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: l
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: foreign
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: milestone
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: sic
# Element tag: expan
# Element tag: corr
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: sic
# Element tag: corr
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: seg
# Element tag: milestone
# Element tag: l
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: foreign
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: seg
# Element tag: l
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: note
# Element tag: ref
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: expan
# Element tag: expan
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: foreign
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: milestone
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: lb
# Element tag: lb
# Element tag: foreign
# Element tag: lb
# Element tag: l
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: milestone
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: space
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: l
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: sic
# Element tag: expan
# Element tag: corr
# Element tag: expan
# Element tag: milestone
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: sic
# Element tag: corr
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: add
# Element tag: note
# Element tag: ref
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: sic
# Element tag: expan
# Element tag: corr
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: sic
# Element tag: hi
# Element tag: corr
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: seg
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: sic
# Element tag: corr
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: lb
# Element tag: lb
# Element tag: lb
# Element tag: lb
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: milestone
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: add
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: lb
# Element tag: lb
# Element tag: lb
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: lg
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: sic
# Element tag: hi
# Element tag: hi
# Element tag: corr
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: sic
# Element tag: corr
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: milestone
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: sic
# Element tag: corr
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: orig
# Element tag: reg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: sic
# Element tag: corr
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: seg
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: milestone
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: expan
# Element tag: expan
# Element tag: sic
# Element tag: corr
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: seg
# Element tag: hi
# Element tag: hi
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: l
# Element tag: sic
# Element tag: hi
# Element tag: corr
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: orig
# Element tag: reg
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: seg
# Element tag: expan
# Element tag: hi
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: orig
# Element tag: reg
# Element tag: l
# Element tag: hi
# Element tag: lg
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: note
# Element tag: ref
# Element tag: hi
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: expan
# Element tag: hi
# Element tag: seg
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: expan
# Element tag: seg
# Element tag: milestone
# Element tag: l
# Element tag: sic
# Element tag: corr
# Element tag: hi
# Element tag: expan
# Element tag: expan
# Element tag: expan
# Element tag: l
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: trailer
# Element tag: foreign
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi
# Element tag: hi

# %% [markdown]
# We now see, there are so many tags of certain names. In our tree variable we can then look for specific types of tags such as dates by getting the "text" attribute out of each element.

# %%
for elem in iter_:
    if elem.tag == "date":
        print(elem.text)
# Out:
# 2002
# late 14th or early 15th century
# 199901

# %% [markdown]
# This allows us for easier search based on the attributes we are looking for such as dates or names, I've found a sample XML function that parses through XML file using element tree and prints out the tags inside the file below:

# %%
def parseXML(xml_file):
    """
    Parse XML with ElementTree
    """
    tree = ET.ElementTree(file=xml_file)
    print(tree.getroot())
    root = tree.getroot()
    print("tag=%s, attrib=%s" % (root.tag, root.attrib))
 
    for child in root:
        print("child tag: " + child.tag, child.attrib)
        for step_child in child:
            print("step child tag: "+ step_child.tag)
 
    # iterate over the entire tree
    print("-" * 40) 
    print("Iterating using a tree iterator") 
    print("-" * 40) 
    iter_ = tree.getiterator()
    for elem in iter_:
        if elem.text != None:
            print("Elem Tag: " + elem.tag, "Elem Text: " + elem.text)

        
parseXML('data/ppexample.xml')
# Out:
# <Element 'TEI.2' at 0x10aa7da48>
# tag=TEI.2, attrib={'id': 'F'}
# child tag: teiHeader {}
# step child tag: fileDesc
# step child tag: encodingDesc
# step child tag: profileDesc
# step child tag: revisionDesc
# child tag: text {}
# step child tag: front
# step child tag: body
# ----------------------------------------
# Iterating using a tree iterator
# ----------------------------------------
# Elem Tag: title Elem Text:  The Piers Plowman Electronic Archive, Vol. 1: Oxford, Corpus Christi College, MS 201 (F) – Passus 4
# Elem Tag: author Elem Text: William  Langland
# Elem Tag: editor Elem Text: Edited by Robert Adams, Hoyt N. Duggan, Eric Eliason, Ralph Hanna, John Price-Wilkin, and Thorlac Turville-Petre
# Elem Tag: editor Elem Text: Associate Editors:  M. Gail Duggan and Catherine A. Farley
# Elem Tag: resp Elem Text:
# Elem Tag: hi Elem Text: Graduate Research Assistants
# Elem Tag: name Elem Text:  William O. Albertini, Patricia Bart, Michael Blum, Cristina
# Maria Cervone, John H. Chaffin, Nancy L. Renwick Clendenon, Christopher J. Copeland, David Cox, Stephen C. Martin, Stephen J. Ramsay, and Dominique Woodall.
# Elem Tag: resp Elem Text:
# Elem Tag: hi Elem Text: Computer Consultants and Programmers
# Elem Tag: name Elem Text:  Oludotun Akinola, Robert W. Bingler, David Cosca, Karen Dietz,
# Susan Gants, Nigel Kerr, Susan Munson, Daniel Pitti, David Seaman, Thornton Staples, John Unsworth, and Peter Yadlowsky.
# Elem Tag: publisher Elem Text: Medieval Academy of America
#
# Elem Tag: pubPlace Elem Text: Cambridge, MA
#
# Elem Tag: idno Elem Text: ISBN: 0-472-002???
# Elem Tag: p Elem Text: Beta Version of 2nd edition: NOT FOR DISTRIBUTION
# Elem Tag: p Elem Text: copyright 2002, by SEENET
# Elem Tag: date Elem Text: 2002
# Elem Tag: p Elem Text: SEENET A.1
#
# Elem Tag: title Elem Text: Oxford, Corpus Christi College, Oxford, MS 201
# Elem Tag: p Elem Text:
#
# Elem Tag: extent Elem Text:
# Elem Tag: publisher Elem Text:
#
# Elem Tag: pubPlace Elem Text:
#
# Elem Tag: date Elem Text: late 14th or early 15th century
# Elem Tag: idno Elem Text: Source copy consulted: Oxford, Corpus Christi College, Oxford, MS 201
# Elem Tag: p Elem Text:
#
# Elem Tag: head Elem Text: Attribute Values
# Elem Tag: item Elem Text:
#
# Elem Tag: label Elem Text: br
# Elem Tag: term Elem Text: brown ink
# Elem Tag: item Elem Text:
#
# Elem Tag: label Elem Text: ab
# Elem Tag: term Elem Text: anglicana bastarda
# Elem Tag: item Elem Text:
#
# Elem Tag: label Elem Text: it
# Elem Tag: term Elem Text: italic
# Elem Tag: item Elem Text:
#
# Elem Tag: label Elem Text: lc
# Elem Tag: term Elem Text: Lombard Cap
# Elem Tag: item Elem Text:
#
# Elem Tag: label Elem Text: o[number]
# Elem Tag: term Elem Text: ornamented capital, N lines high
# Elem Tag: item Elem Text:
#
# Elem Tag: label Elem Text: rb
# Elem Tag: term Elem Text: rubricated
# Elem Tag: item Elem Text:
#
# Elem Tag: label Elem Text: tr
# Elem Tag: term Elem Text: touched in red
# Elem Tag: item Elem Text:
#
# Elem Tag: label Elem Text: tx
# Elem Tag: term Elem Text: textura
# Elem Tag: item Elem Text:
#
# Elem Tag: label Elem Text: ul
# Elem Tag: term Elem Text: underlined
# Elem Tag: item Elem Text:
#
# Elem Tag: label Elem Text: ur
# Elem Tag: term Elem Text: underlined in red
# Elem Tag: item Elem Text:
#
# Elem Tag: label Elem Text: gr
# Elem Tag: term Elem Text: green ink
# Elem Tag: item Elem Text:
#
# Elem Tag: label Elem Text: bl
# Elem Tag: term Elem Text: blue ink
# Elem Tag: language Elem Text: Latin
# Elem Tag: language Elem Text: French
# Elem Tag: language Elem Text: German
# Elem Tag: term Elem Text: poetry
#
# Elem Tag: term Elem Text: masculine
#
# Elem Tag: date Elem Text: 199901
#
# Elem Tag: resp Elem Text: cataloger
#
# Elem Tag: name Elem Text: Jackie Shieh
#
# Elem Tag: item Elem Text: New header created
#
# Elem Tag: head Elem Text:
#
# Elem Tag: note Elem Text: This
# folio marker does not represent a leaf boundary at this point, but it is
# included to make it possible to display the facsimile image from this passus file.
# Elem Tag: hi Elem Text: I
# Elem Tag: hi Elem Text: ncipit Passus Qvartus.
# Elem Tag: hi Elem Text: N
# Elem Tag: hi Elem Text: O
# Elem Tag: ref Elem Text: F.4.1:
# Elem Tag: hi Elem Text: Meede
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: I
# Elem Tag: seg Elem Text: -
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: A
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: C
# Elem Tag: expan Elem Text: i
# Elem Tag: hi Elem Text: T
# Elem Tag: hi Elem Text: Meed
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: e
# Elem Tag: orig Elem Text: a tese
# Elem Tag: reg Elem Text: at ese
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: W
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: h
# Elem Tag: hi Elem Text: h
# Elem Tag: hi Elem Text: b
# Elem Tag: hi Elem Text: w
# Elem Tag: hi Elem Text: w
# Elem Tag: hi Elem Text: ll
# Elem Tag: hi Elem Text: l
# Elem Tag: ref Elem Text: F.4.7:
# Elem Tag: hi Elem Text: IIII
# Elem Tag: expan Elem Text: us
# Elem Tag: hi Elem Text: I
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: e
# Elem Tag: ref Elem Text: F.4.8:
# Elem Tag: hi Elem Text: gyltis
# Elem Tag: hi Elem Text: gilt
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: C
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: H
# Elem Tag: hi Elem Text: Meede
# Elem Tag: ref Elem Text: F.4.10:
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: C
# Elem Tag: expan Elem Text: con
# Elem Tag: expan Elem Text: n
# Elem Tag: ref Elem Text: F.4.11:
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: Meede
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: S
# Elem Tag: expan Elem Text: m
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: I
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: I
# Elem Tag: hi Elem Text: I
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: T
# Elem Tag: expan Elem Text: con
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: C
# Elem Tag: hi Elem Text: Þ
# Elem Tag: hi Elem Text: Meede
# Elem Tag: expan Elem Text: o
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: k
# Elem Tag: hi Elem Text: T
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: F
# Elem Tag: sic Elem Text: co
# Elem Tag: expan Elem Text: n
# Elem Tag: corr Elem Text: consye[n]cys
# Elem Tag: ref Elem Text: F.4.20:
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: Meede
# Elem Tag: hi Elem Text: O
# Elem Tag: hi Elem Text: C
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: R
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: ref Elem Text: F.4.24:
# Elem Tag: hi Elem Text: rychesse
# Elem Tag: hi Elem Text: richesses
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: L
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: C
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: o
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: n
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: T
# Elem Tag: hi Elem Text: L
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: ur
# Elem Tag: hi Elem Text: S
# Elem Tag: expan Elem Text: n
# Elem Tag: ref Elem Text: F.4.33:
# Elem Tag: hi Elem Text: clerkys
# Elem Tag: hi Elem Text: leode
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: ref Elem Text: F.4.34:
# Elem Tag: hi Elem Text: Bx
# Elem Tag: seg Elem Text: -
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: sic Elem Text: knokke
# Elem Tag: corr Elem Text: k[l]okke
# Elem Tag: ref Elem Text: F.4.35:
# Elem Tag: hi Elem Text: knokke
# Elem Tag: hi Elem Text: klokke
# Elem Tag: title Elem Text: Piers Plowman
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: C
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: T
# Elem Tag: hi Elem Text: Meede
# Elem Tag: expan Elem Text: a
# Elem Tag: ref Elem Text: F.4.37:
# Elem Tag: hi Elem Text: þe
# Elem Tag: hi Elem Text: þis
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: Fals
# Elem Tag: hi Elem Text: I
# Elem Tag: seg Elem Text: -
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: A
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: C
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: con
# Elem Tag: expan Elem Text: ur
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: Þ
# Elem Tag: hi Elem Text: Meede
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: ur
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: ro
# Elem Tag: hi Elem Text: W
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: A
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: W
# Elem Tag: hi Elem Text: h
# Elem Tag: hi Elem Text: h
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: l h
# Elem Tag: hi Elem Text: W
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: er
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: S
# Elem Tag: expan Elem Text: e
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: Ȝ
# Elem Tag: expan Elem Text: uo
# Elem Tag: hi Elem Text: Meed
# Elem Tag: sic Elem Text: is
# Elem Tag: corr Elem Text: [n]is
# Elem Tag: expan Elem Text: er
# Elem Tag: ref Elem Text: F.4.52:
# Elem Tag: hi Elem Text: A
# Elem Tag: hi Elem Text: A
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: sic Elem Text: y
# Elem Tag: corr Elem Text: y [ne]
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: n
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: er
# Elem Tag: seg Elem Text: -
# Elem Tag: ref Elem Text: F.4.54:
# Elem Tag: hi Elem Text: A
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: ref Elem Text: F.4.55:
# Elem Tag: hi Elem Text: ech a
# Elem Tag: hi Elem Text: euery
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: er
# Elem Tag: ref Elem Text: F.4.55:
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: ra
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: N
# Elem Tag: expan Elem Text: er
# Elem Tag: ref Elem Text: F.4.58:
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: ri
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: B
# Elem Tag: ref Elem Text: F.4.60:
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text: N
# Elem Tag: hi Elem Text: esciat sinistra   quid faciat dextera.
# Elem Tag: hi Elem Text: L
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: ir
# Elem Tag: hi Elem Text: W
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: o
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: F
# Elem Tag: sic Elem Text: dos
# Elem Tag: corr Elem Text: do[n]
# Elem Tag: ref Elem Text: F.4.64:
# Elem Tag: expan Elem Text: er
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: a
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: Þ
# Elem Tag: hi Elem Text: C
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: &
# Elem Tag: ref Elem Text: F.4.67:
# Elem Tag: ref Elem Text: F.4.67:
# Elem Tag: hi Elem Text: vpon
# Elem Tag: hi Elem Text: on
# Elem Tag: sic Elem Text: pynyge
# Elem Tag: corr Elem Text: pyny[n]ge
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: ref Elem Text: F.4.69:
# Elem Tag: hi Elem Text: vpon
# Elem Tag: hi Elem Text: on
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: T
# Elem Tag: expan Elem Text: ar
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: W
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: N
# Elem Tag: ref Elem Text: F.4.75:
# Elem Tag: hi Elem Text: ye
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: ra
# Elem Tag: hi Elem Text: O
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: O
# Elem Tag: expan Elem Text: re
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: O
# Elem Tag: expan Elem Text: ra
# Elem Tag: sic Elem Text: mey
# Elem Tag: expan Elem Text: n
# Elem Tag: corr Elem Text: meyn[ten]e
# Elem Tag: hi Elem Text: F
# Elem Tag: ref Elem Text: F.4.80:
# Elem Tag: hi Elem Text: Lord
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text: loue
# Elem Tag: expan Elem Text: uod
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: m
# Elem Tag: expan Elem Text: m
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: K
# Elem Tag: hi Elem Text: S
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: T
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: L
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: I
# Elem Tag: hi Elem Text: gnis deuorabit tabernac
# Elem Tag: expan Elem Text: u
# Elem Tag: expan Elem Text: um
# Elem Tag: expan Elem Text: er
# Elem Tag: ref Elem Text: F.4.85:
# Elem Tag: hi Elem Text: accipiunt munera
# Elem Tag: hi Elem Text: A
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: G
# Elem Tag: seg Elem Text: -
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: e
# Elem Tag: ref Elem Text: F.4.89:
# Elem Tag: hi Elem Text: offyȝs
# Elem Tag: hi Elem Text: offices
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: Þ
# Elem Tag: hi Elem Text: k
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: b
# Elem Tag: hi Elem Text: h
# Elem Tag: corr Elem Text: browhtyn [hire]
# Elem Tag: hi Elem Text: b
# Elem Tag: hi Elem Text: bl
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: A
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text:
# Elem Tag: hi Elem Text: Meed
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: o
# Elem Tag: expan Elem Text: m
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: o
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: o
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: o
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: ra
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: n
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: o
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: con
# Elem Tag: expan Elem Text: ra
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: I
# Elem Tag: expan Elem Text: o
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: Ȝ
# Elem Tag: hi Elem Text: L
# Elem Tag: hi Elem Text: q
# Elem Tag: expan Elem Text: uod
# Elem Tag: hi Elem Text: L
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: L
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: ur
# Elem Tag: sic Elem Text: hange
# Elem Tag: corr Elem Text: hange [me]
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: Co
# Elem Tag: expan Elem Text: n
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: B
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: k
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: C
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: C
# Elem Tag: hi Elem Text: T
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: W
# Elem Tag: expan Elem Text: o
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: m
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: uod
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: F
# Elem Tag: ref Elem Text: F.4.108:
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: Q
# Elem Tag: expan Elem Text: uo
# Elem Tag: hi Elem Text: Co
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: ri
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: &
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: n
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: ri
# Elem Tag: ref Elem Text: F.4.113:
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text: B
# Elem Tag: ref Elem Text: F.4.114:
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: L
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: Ȝ
# Elem Tag: expan Elem Text: e
# Elem Tag: ref Elem Text: F.4.116:
# Elem Tag: hi Elem Text: hire
# Elem Tag: expan Elem Text: e
# Elem Tag: ref Elem Text: F.4.116:
# Elem Tag: hi Elem Text: fayre
# Elem Tag: hi Elem Text: false
# Elem Tag: hi Elem Text: &
# Elem Tag: seg Elem Text: -
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: m
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: B
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: S
# Elem Tag: ref Elem Text: F.2.122:
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text: to
# Elem Tag: hi Elem Text: B
# Elem Tag: hi Elem Text: S
# Elem Tag: hi Elem Text: S
# Elem Tag: expan Elem Text: m
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: re
# Elem Tag: hi Elem Text: B
# Elem Tag: hi Elem Text: S
# Elem Tag: hi Elem Text: S
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: ri
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: &
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: T
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: T
# Elem Tag: expan Elem Text: con
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: C
# Elem Tag: ref Elem Text: F.4.132:
# Elem Tag: hi Elem Text: klokiþ
# Elem Tag: title Elem Text: OED
# Elem Tag: title Elem Text: MED
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: &
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: e
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: S
# Elem Tag: hi Elem Text: h
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: A
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: s
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: F
# Elem Tag: add Elem Text: is
# Elem Tag: expan Elem Text: ri
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: ro
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: S
# Elem Tag: expan Elem Text: e
# Elem Tag: seg Elem Text: -
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: re
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: &
# Elem Tag: ref Elem Text: F.4.140:
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: and lotebies
# Elem Tag: expan Elem Text: e
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: &
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: seg Elem Text: -
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: e
# Elem Tag: add Elem Text: is
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: B
# Elem Tag: hi Elem Text: I
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: I
# Elem Tag: ref Elem Text: F.4.144:
# Elem Tag: hi Elem Text: þe
# Elem Tag: hi Elem Text: youre
# Elem Tag: hi Elem Text: I
# Elem Tag: hi Elem Text: &
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: S
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: Ȝ
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: W
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: re
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: B
# Elem Tag: hi Elem Text: B
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: C
# Elem Tag: hi Elem Text: C
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: L
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: L
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: &
# Elem Tag: sic Elem Text: alle
# Elem Tag: corr Elem Text: alle [þat]
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: m
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: ref Elem Text: F.4.157:
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text: T
# Elem Tag: hi Elem Text: H
# Elem Tag: ref Elem Text: F.4.158:
# Elem Tag: hi Elem Text: M
# Elem Tag: ref Elem Text: F.4.158:
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: ra
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: ra
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: ra
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: E
# Elem Tag: expan Elem Text: o
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: C
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: N
# Elem Tag: hi Elem Text: L
# Elem Tag: hi Elem Text: q
# Elem Tag: expan Elem Text: uo
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: L
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: W
# Elem Tag: expan Elem Text: yr
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: a
# Elem Tag: ref Elem Text: F.4.166:
# Elem Tag: hi Elem Text: þat
# Elem Tag: expan Elem Text: o
# Elem Tag: hi Elem Text:
# Elem Tag: hi Elem Text: C
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: N
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: o
# Elem Tag: expan Elem Text: o
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: o
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: &
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: ri
# Elem Tag: ref Elem Text: F.4.170:
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: o
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: o
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: o
# Elem Tag: sic Elem Text: defamed
# Elem Tag: corr Elem Text: defamed [me]
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: ru
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: er
# Elem Tag: ref Elem Text: F.4.175:
# Elem Tag: hi Elem Text: knyght
# Elem Tag: hi Elem Text: kyng
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: ri
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: N
# Elem Tag: expan Elem Text: o
# Elem Tag: ref Elem Text: F.4.176:
# Elem Tag: hi Elem Text: dede
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text: kynge
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: N
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: o
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: l
# Elem Tag: hi Elem Text: hl
# Elem Tag: expan Elem Text: o
# Elem Tag: hi Elem Text: s
# Elem Tag: hi Elem Text: h
# Elem Tag: ref Elem Text: F.4.178:
# Elem Tag: hi Elem Text: F
# Elem Tag: corr Elem Text: Crope
# Elem Tag: hi Elem Text: C
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: o
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: ir
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: o
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: o
# Elem Tag: ref Elem Text: F.4.183:
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: C
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: L
# Elem Tag: hi Elem Text: I
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: I
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: m
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: H
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: I
# Elem Tag: hi Elem Text: H
# Elem Tag: sic Elem Text: have
# Elem Tag: corr Elem Text: have [be]
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: Þ
# Elem Tag: ref Elem Text: F.4.193:
# Elem Tag: hi Elem Text: lond
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text: blood
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: o
# Elem Tag: hi Elem Text: C
# Elem Tag: expan Elem Text: o
# Elem Tag: expan Elem Text: con
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: T
# Elem Tag: hi Elem Text: L
# Elem Tag: ref Elem Text: F.4.195:
# Elem Tag: hi Elem Text: Lordchepe
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: er
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: I
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: T
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: m
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: ir
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: m
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: m
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: E
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: E
# Elem Tag: hi Elem Text: L
# Elem Tag: expan Elem Text: is
# Elem Tag: hi Elem Text: Þ
# Elem Tag: ref Elem Text: F.4.202:
# Elem Tag: hi Elem Text: ȝoomen
# Elem Tag: hi Elem Text: yonge men
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: Þ
# Elem Tag: hi Elem Text: P
# Elem Tag: hi Elem Text: p
# Elem Tag: expan Elem Text: re
# Elem Tag: expan Elem Text: re
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: n
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: T
# Elem Tag: hi Elem Text: Meede
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: n
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: ref Elem Text: F.4.207:
# Elem Tag: hi Elem Text: beggyng
# Elem Tag: hi Elem Text: biddynge
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: ro
# Elem Tag: expan Elem Text: e
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: Þ
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: a
# Elem Tag: ref Elem Text: F.4.210:
# Elem Tag: hi Elem Text: P
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: re
# Elem Tag: hi Elem Text: &
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: A
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: ra
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: re
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: M
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: N
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: n
# Elem Tag: ref Elem Text: F.4.216:
# Elem Tag: hi Elem Text: T
# Elem Tag: hi Elem Text: h
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: k
# Elem Tag: expan Elem Text: con
# Elem Tag: expan Elem Text: ri
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: N
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: N
# Elem Tag: hi Elem Text: q
# Elem Tag: expan Elem Text: uod
# Elem Tag: hi Elem Text:
# Elem Tag: hi Elem Text: c
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: ur
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: ra
# Elem Tag: hi Elem Text: T
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: Þ
# Elem Tag: hi Elem Text: p
# Elem Tag: expan Elem Text: ro
# Elem Tag: expan Elem Text: et
# Elem Tag: expan Elem Text: re
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: S
# Elem Tag: hi Elem Text:
# Elem Tag: hi Elem Text: D
# Elem Tag: expan Elem Text: omi
# Elem Tag: expan Elem Text: ui
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: u
# Elem Tag: expan Elem Text: que
# Elem Tag: expan Elem Text: ui
# Elem Tag: expan Elem Text: ui
# Elem Tag: sic Elem Text: imoce
# Elem Tag: expan Elem Text: n
# Elem Tag: corr Elem Text: i[nn]ocens
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: us
# Elem Tag: expan Elem Text: n
# Elem Tag: ref Elem Text: F.4.223:
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text: tuo
# Elem Tag: hi Elem Text: H
# Elem Tag: hi Elem Text: L
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: E
# Elem Tag: ref Elem Text: F.4.225:
# Elem Tag: hi Elem Text: askede
# Elem Tag: hi Elem Text: askeþ
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: d
# Elem Tag: expan Elem Text: m
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: s
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text:
# Elem Tag: hi Elem Text: Q
# Elem Tag: expan Elem Text: ui
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: ur
# Elem Tag: expan Elem Text: u
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: ur
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: B
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: ref Elem Text: F.4.231:
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: m
# Elem Tag: ref Elem Text: F.4.233:
# Elem Tag: hi Elem Text: trew
# Elem Tag: hi Elem Text: truþe
# Elem Tag: hi Elem Text: men
# Elem Tag: hi Elem Text: S
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: O
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: s
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: on
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: ri
# Elem Tag: hi Elem Text: T
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: S
# Elem Tag: ref Elem Text: F.4.239:
# Elem Tag: hi Elem Text: X
# Elem Tag: hi Elem Text: In q
# Elem Tag: expan Elem Text: uo
# Elem Tag: expan Elem Text: um
# Elem Tag: expan Elem Text: us
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: ui
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: ra
# Elem Tag: expan Elem Text: um
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: st
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: us
# Elem Tag: hi Elem Text: H
# Elem Tag: expan Elem Text: a
# Elem Tag: ref Elem Text: F.4.241:
# Elem Tag: hi Elem Text: Note
# Elem Tag: hi Elem Text: H
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: B
# Elem Tag: hi Elem Text: p
# Elem Tag: expan Elem Text: re
# Elem Tag: hi Elem Text: p
# Elem Tag: expan Elem Text: ar
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: re
# Elem Tag: hi Elem Text: Þ
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: Ame
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: L
# Elem Tag: hi Elem Text: l
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: ri
# Elem Tag: hi Elem Text: I
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: N
# Elem Tag: hi Elem Text: M
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: I
# Elem Tag: ref Elem Text: F.4.249:
# Elem Tag: hi Elem Text: a
# Elem Tag: hi Elem Text: Permvtacioun
# Elem Tag: hi Elem Text: P
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: er
# Elem Tag: seg Elem Text: -
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: o
# Elem Tag: expan Elem Text: er
# Elem Tag: foreign Elem Text: regu
# Elem Tag: expan Elem Text: m
# Elem Tag: expan Elem Text: o
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: W
# Elem Tag: hi Elem Text: S
# Elem Tag: hi Elem Text: G
# Elem Tag: hi Elem Text: S
# Elem Tag: hi Elem Text: S
# Elem Tag: hi Elem Text: p
# Elem Tag: expan Elem Text: ro
# Elem Tag: expan Elem Text: et
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: A
# Elem Tag: hi Elem Text: A
# Elem Tag: hi Elem Text: S
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: e
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: Þ
# Elem Tag: hi Elem Text: S
# Elem Tag: hi Elem Text: S
# Elem Tag: expan Elem Text: m
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: o
# Elem Tag: expan Elem Text: m
# Elem Tag: ref Elem Text: F.4.256:
# Elem Tag: hi Elem Text: his
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: W
# Elem Tag: hi Elem Text: A
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: o
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: m
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: ref Elem Text: F.4.259:
# Elem Tag: hi Elem Text: M
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: o
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: e
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: M
# Elem Tag: sic Elem Text: þy
# Elem Tag: expan Elem Text: n
# Elem Tag: corr Elem Text: þyn[g]
# Elem Tag: ref Elem Text: F.4.262:
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text: Cx
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: o
# Elem Tag: expan Elem Text: e
# Elem Tag: l Elem Text:
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: &
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: O
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: ro
# Elem Tag: expan Elem Text: et
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: Þ
# Elem Tag: hi Elem Text: S
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: n
# Elem Tag: ref Elem Text: F.4.268:
# Elem Tag: hi Elem Text: endede
# Elem Tag: hi Elem Text: ende(n)
# Elem Tag: hi Elem Text: S
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: m
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: m
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: I
# Elem Tag: hi Elem Text: q
# Elem Tag: expan Elem Text: uod
# Elem Tag: hi Elem Text: c
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: r
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: A
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: S
# Elem Tag: sic Elem Text: fle
# Elem Tag: corr Elem Text: [s]le
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: d
# Elem Tag: expan Elem Text: aui
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: ri
# Elem Tag: ref Elem Text: F.4.280:
# Elem Tag: hi Elem Text: B
# Elem Tag: hi Elem Text: S
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: er
# Elem Tag: ref Elem Text: F.4.281:
# Elem Tag: hi Elem Text: he
# Elem Tag: hi Elem Text: she
# Elem Tag: hi Elem Text: B
# Elem Tag: hi Elem Text: love
# Elem Tag: hi Elem Text: lowenesse
# Elem Tag: hi Elem Text: lewte
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: ri
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: t
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: re
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: t
# Elem Tag: expan Elem Text: re
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: L
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: S
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: N
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: B
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: is
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: L
# Elem Tag: hi Elem Text: L
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: B
# Elem Tag: hi Elem Text: l
# Elem Tag: expan Elem Text: n
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: n
# Elem Tag: expan Elem Text: ota
# Elem Tag: hi Elem Text: &
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: &
# Elem Tag: ref Elem Text: F.4.292:
# Elem Tag: hi Elem Text: a
# Elem Tag: hi Elem Text: pees
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: ar
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: n
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: ref Elem Text: F.4.296:
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: E
# Elem Tag: hi Elem Text: S
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: I
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: E
# Elem Tag: hi Elem Text: t conflabu
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: E
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: O
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: ref Elem Text: F.4.302:
# Elem Tag: hi Elem Text: lese
# Elem Tag: hi Elem Text: spille
# Elem Tag: expan Elem Text: m
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: P
# Elem Tag: expan Elem Text: ar
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: P
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: H
# Elem Tag: hi Elem Text: F
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: m
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: S
# Elem Tag: expan Elem Text: ir
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: O
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: N
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: E
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: e
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: A
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: re
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: n
# Elem Tag: ref Elem Text: F.4.314:
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: N
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: l Elem Text: & what smeþ þ
# Elem Tag: expan Elem Text: a
# Elem Tag: ref Elem Text: F.4.316:
# Elem Tag: hi Elem Text: smythie
# Elem Tag: hi Elem Text: smyteth
# Elem Tag: hi Elem Text: smyþeþ
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: N
# Elem Tag: hi Elem Text: on leuab
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: ra
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: m
# Elem Tag: expan Elem Text: m
# Elem Tag: l Elem Text: & er þis
# Elem Tag: hi Elem Text: F
# Elem Tag: ref Elem Text: F.4.319:
# Elem Tag: expan Elem Text: n
# Elem Tag: l Elem Text: & þe
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: I
# Elem Tag: ref Elem Text: F.4.320:
# Elem Tag: hi Elem Text: to
# Elem Tag: hi Elem Text: Iewis
# Elem Tag: expan Elem Text: ur
# ...
# Elem Tag: hi Elem Text: w
# Elem Tag: hi Elem Text: w
# Elem Tag: expan Elem Text: n
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: T
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: k
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: Þ
# Elem Tag: hi Elem Text: k
# Elem Tag: hi Elem Text: b
# Elem Tag: hi Elem Text: C
# Elem Tag: hi Elem Text: b
# Elem Tag: hi Elem Text: h
# Elem Tag: hi Elem Text: C
# Elem Tag: hi Elem Text: b
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: wro
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: A
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: C
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: m
# Elem Tag: add Elem Text: in
# Elem Tag: ref Elem Text: F.4.427:
# Elem Tag: hi Elem Text: in
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: er
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: A
# Elem Tag: hi Elem Text: q
# Elem Tag: expan Elem Text: uod
# Elem Tag: hi Elem Text: Wi
# Elem Tag: hi Elem Text: dom
# Elem Tag: hi Elem Text: B
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: ri
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: &
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: a
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: A
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: w
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: Þ
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: er
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: Meede
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: er
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: ro
# Elem Tag: expan Elem Text: re
# Elem Tag: hi Elem Text: H
# Elem Tag: hi Elem Text: q
# Elem Tag: expan Elem Text: uod
# Elem Tag: hi Elem Text: s
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: w
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: Þ
# Elem Tag: hi Elem Text: P
# Elem Tag: expan Elem Text: ra
# Elem Tag: hi Elem Text: H
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: &
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: m
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: S
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: Meed
# Elem Tag: expan Elem Text: n
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: N
# Elem Tag: expan Elem Text: uod
# Elem Tag: hi Elem Text: W
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: F
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: B
# Elem Tag: hi Elem Text: r
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: r
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: c
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: Meede
# Elem Tag: hi Elem Text: p
# Elem Tag: expan Elem Text: ar
# Elem Tag: expan Elem Text: ur
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text:
# Elem Tag: hi Elem Text: re
# Elem Tag: expan Elem Text: n
# Elem Tag: seg Elem Text: -
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: N
# Elem Tag: hi Elem Text: q
# Elem Tag: expan Elem Text: uod
# Elem Tag: hi Elem Text: R
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: ra
# Elem Tag: hi Elem Text: T
# Elem Tag: hi Elem Text: L
# Elem Tag: hi Elem Text: L
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: ri
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: P
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: &
# Elem Tag: sic Elem Text:
# Elem Tag: hi Elem Text: C
# Elem Tag: hi Elem Text: C
# Elem Tag: corr Elem Text: Chy[l]d[r]ene Chyr[y]synge
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: C
# Elem Tag: sic Elem Text: Po
# Elem Tag: corr Elem Text: Po[re & fede]
# Elem Tag: ref Elem Text: F.4.461:
# Elem Tag: hi Elem Text: Po
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: A
# Elem Tag: hi Elem Text: s
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: B
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: p
# Elem Tag: expan Elem Text: re
# Elem Tag: hi Elem Text: p
# Elem Tag: expan Elem Text: re
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: l
# Elem Tag: hi Elem Text: k
# Elem Tag: hi Elem Text: l
# Elem Tag: hi Elem Text: b
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: ro
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: is
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: S
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: I
# Elem Tag: expan Elem Text: e
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: G
# Elem Tag: hi Elem Text: &
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: N
# Elem Tag: expan Elem Text: ir
# Elem Tag: expan Elem Text: ra
# Elem Tag: expan Elem Text: ra
# Elem Tag: expan Elem Text: ir
# Elem Tag: hi Elem Text: V
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: ar
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: ri
# Elem Tag: hi Elem Text: E
# Elem Tag: hi Elem Text: p
# Elem Tag: expan Elem Text: ro
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: q
# Elem Tag: expan Elem Text: uod
# Elem Tag: ref Elem Text: F.4.476:
# Elem Tag: expan Elem Text: uod
# Elem Tag: hi Elem Text: R
# Elem Tag: sic Elem Text: rewþe
# Elem Tag: corr Elem Text: [no] rewþe
# Elem Tag: hi Elem Text: W
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: ri
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: ir
# Elem Tag: hi Elem Text: I
# Elem Tag: expan Elem Text: n
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: q
# Elem Tag: expan Elem Text: uod
# Elem Tag: hi Elem Text: h
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: k
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: S
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: N
# Elem Tag: expan Elem Text: ra
# Elem Tag: hi Elem Text: N
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: nullu
# Elem Tag: expan Elem Text: m
# Elem Tag: expan Elem Text: m
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: inpunitu
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: nullum bonu
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: irremuneratu
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: L
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: s
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: k
# Elem Tag: hi Elem Text: &
# Elem Tag: orig Elem Text: hewerke
# Elem Tag: reg Elem Text: he werke
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: L
# Elem Tag: l Elem Text: &
# Elem Tag: hi Elem Text: L
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: L
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: A
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: C
# Elem Tag: expan Elem Text: n
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: T
# Elem Tag: sic Elem Text: clawse
# Elem Tag: corr Elem Text: [þis] clawse
# Elem Tag: expan Elem Text: ro
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: Meede
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: S
# Elem Tag: hi Elem Text: W
# Elem Tag: hi Elem Text: Wyȝsdom
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: Meede
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: I
# Elem Tag: hi Elem Text: q
# Elem Tag: expan Elem Text: uod
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: R
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text:
# Elem Tag: hi Elem Text: re
# Elem Tag: hi Elem Text: ou
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: w
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: er
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: A
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: Þ
# Elem Tag: hi Elem Text: Meekness
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: meede
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: Þ
# Elem Tag: hi Elem Text: Love
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: L
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: Wh
# Elem Tag: hi Elem Text: l
# Elem Tag: hi Elem Text: M
# Elem Tag: ref Elem Text: F.4.505:
# Elem Tag: hi Elem Text: V
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: Þ
# Elem Tag: hi Elem Text: Meed
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: ur
# Elem Tag: hi Elem Text: F
# Elem Tag: expan Elem Text: e
# Elem Tag: ref Elem Text: F.4.508:
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: sic Elem Text: as
# Elem Tag: corr Elem Text: a[n]
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: B
# Elem Tag: hi Elem Text: S
# Elem Tag: hi Elem Text: s
# Elem Tag: expan Elem Text: m
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: s
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: A
# Elem Tag: hi Elem Text: y q
# Elem Tag: expan Elem Text: uod
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: er
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: a
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: Þ
# Elem Tag: hi Elem Text: Moode
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: L
# Elem Tag: ref Elem Text: F.4.515:
# Elem Tag: hi Elem Text: k
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: L
# Elem Tag: hi Elem Text: Meed
# Elem Tag: expan Elem Text: m
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: L
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: Meed
# Elem Tag: expan Elem Text: er
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: ri
# Elem Tag: hi Elem Text: L
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: re
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: B
# Elem Tag: hi Elem Text: r
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: M
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: ri
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: I
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: l
# Elem Tag: expan Elem Text: ur
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: &
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: S
# Elem Tag: hi Elem Text: q
# Elem Tag: expan Elem Text: uod
# Elem Tag: hi Elem Text:
# Elem Tag: hi Elem Text: C
# Elem Tag: hi Elem Text: k
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: I
# Elem Tag: expan Elem Text: n
# Elem Tag: seg Elem Text: -
# Elem Tag: hi Elem Text: A
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: m
# Elem Tag: expan Elem Text: a
# Elem Tag: hi Elem Text: q
# Elem Tag: expan Elem Text: uod
# Elem Tag: hi Elem Text: Resou
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: us
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: I
# Elem Tag: expan Elem Text: e
# Elem Tag: hi Elem Text: B
# Elem Tag: expan Elem Text: m
# Elem Tag: orig Elem Text: tome
# Elem Tag: reg Elem Text: to me
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: Þ
# Elem Tag: expan Elem Text: uod
# Elem Tag: hi Elem Text: k
# Elem Tag: hi Elem Text: L
# Elem Tag: hi Elem Text: T
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: e
# Elem Tag: expan Elem Text: a
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: C
# Elem Tag: expan Elem Text: is
# Elem Tag: hi Elem Text: B
# Elem Tag: hi Elem Text:
# Elem Tag: hi Elem Text: resou
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: o
# Elem Tag: orig Elem Text: frome
# Elem Tag: reg Elem Text: fro me
# Elem Tag: hi Elem Text: F
# Elem Tag: hi Elem Text: ¶
# Elem Tag: hi Elem Text: I
# Elem Tag: expan Elem Text: uod
# Elem Tag: expan Elem Text: n
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: er
# Elem Tag: ref Elem Text: F.4.534:
# Elem Tag: hi Elem Text: Bx
# Elem Tag: hi Elem Text: &
# Elem Tag: hi Elem Text: q
# Elem Tag: expan Elem Text: uod
# Elem Tag: hi Elem Text: k
# Elem Tag: seg Elem Text: -
# Elem Tag: expan Elem Text: o
# Elem Tag: hi Elem Text: A
# Elem Tag: expan Elem Text: e
# Elem Tag: seg Elem Text: -
# Elem Tag: sic Elem Text: /
# Elem Tag: corr Elem Text: [¶]
# Elem Tag: hi Elem Text: T
# Elem Tag: expan Elem Text: i
# Elem Tag: expan Elem Text: h
# Elem Tag: expan Elem Text: n
# Elem Tag: hi Elem Text: T
# Elem Tag: hi Elem Text: M
# Elem Tag: hi Elem Text: M
# Elem Tag: trailer Elem Text:
#
# Elem Tag: hi Elem Text: E
# Elem Tag: hi Elem Text: xplicit
# Elem Tag: hi Elem Text: P
# Elem Tag: hi Elem Text: assus
# Elem Tag: hi Elem Text: Q
# Elem Tag: hi Elem Text: uartus.

# %% [markdown]
# Go ahead and play around with the file "data/ppexample.xml", this will allow you to see how XML files can be parsed through and indexed to find actual information.

# %% [markdown]
# ---
# <b>Question 1:</b> Create a list of all the possible Labels and the text and terms associated with them. Labels and terms are XML tags that can be indexed.
#
# <b>Answer: </b> Below

# %%
search = ["label", "term"]
for elem in iter_:
        if elem.text != None and elem.tag in search :
            print("Elem Tag: " + elem.tag + "||" "Elem Text: " + elem.text)
# Out:
# Elem Tag: label||Elem Text: br
# Elem Tag: term||Elem Text: brown ink
# Elem Tag: label||Elem Text: ab
# Elem Tag: term||Elem Text: anglicana bastarda
# Elem Tag: label||Elem Text: it
# Elem Tag: term||Elem Text: italic
# Elem Tag: label||Elem Text: lc
# Elem Tag: term||Elem Text: Lombard Cap
# Elem Tag: label||Elem Text: o[number]
# Elem Tag: term||Elem Text: ornamented capital, N lines high
# Elem Tag: label||Elem Text: rb
# Elem Tag: term||Elem Text: rubricated
# Elem Tag: label||Elem Text: tr
# Elem Tag: term||Elem Text: touched in red
# Elem Tag: label||Elem Text: tx
# Elem Tag: term||Elem Text: textura
# Elem Tag: label||Elem Text: ul
# Elem Tag: term||Elem Text: underlined
# Elem Tag: label||Elem Text: ur
# Elem Tag: term||Elem Text: underlined in red
# Elem Tag: label||Elem Text: gr
# Elem Tag: term||Elem Text: green ink
# Elem Tag: label||Elem Text: bl
# Elem Tag: term||Elem Text: blue ink
# Elem Tag: term||Elem Text: poetry
#
# Elem Tag: term||Elem Text: masculine

# %% [markdown]
# ---

# %% [markdown]
# ## Section 2 Using lxml Module <a id='section 2'></a>

# %% [markdown]
# Now we're going to look at another module, lxml, that allows us to parse through XML files as well. It follows the tree format that XML gives us and parses similar to ElementTree above, however allows us to have a lot more succint of a function than above.

# %%
def parseBookXML(xmlFile):
    """"""
    context = etree.iterparse(xmlFile)
    book_dict = {}
    books = []
    #Searches through elements in the etree, then adds them to a dictionary
    for action, elem in context:
        if not elem.text:
            text = "None"
        else:
            text = elem.text
        print(elem.tag + " => " + text)
        book_dict[elem.tag] = text
        #Can search for certain tags
        if elem.tag == "book":
            books.append(book_dict)
            book_dict = {}
    return books
 
parseBookXML('data/ppexample.xml')
# Out:
# title =>  The Piers Plowman Electronic Archive, Vol. 1: Oxford, Corpus Christi College, MS 201 (F) – Passus 4
# author => William  Langland
# editor => Edited by Robert Adams, Hoyt N. Duggan, Eric Eliason, Ralph Hanna, John Price-Wilkin, and Thorlac Turville-Petre
# editor => Associate Editors:  M. Gail Duggan and Catherine A. Farley
# hi => Graduate Research Assistants
# resp =>
# name =>  William O. Albertini, Patricia Bart, Michael Blum, Cristina
# Maria Cervone, John H. Chaffin, Nancy L. Renwick Clendenon, Christopher J. Copeland, David Cox, Stephen C. Martin, Stephen J. Ramsay, and Dominique Woodall.
# respStmt => None
# hi => Computer Consultants and Programmers
# resp =>
# name =>  Oludotun Akinola, Robert W. Bingler, David Cosca, Karen Dietz,
# Susan Gants, Nigel Kerr, Susan Munson, Daniel Pitti, David Seaman, Thornton Staples, John Unsworth, and Peter Yadlowsky.
# respStmt => None
# titleStmt => None
# publisher => Medieval Academy of America
#
# pubPlace => Cambridge, MA
#
# idno => ISBN: 0-472-002???
# p => Beta Version of 2nd edition: NOT FOR DISTRIBUTION
# p => copyright 2002, by SEENET
# availability => None
# date => 2002
# publicationStmt => None
# p => SEENET A.1
#
# seriesStmt => None
# title => Oxford, Corpus Christi College, Oxford, MS 201
# titleStmt => None
# p =>
#
# editionStmt => None
# extent =>
# publisher =>
#
# pubPlace =>
#
# date => late 14th or early 15th century
# idno => Source copy consulted: Oxford, Corpus Christi College, Oxford, MS 201
# publicationStmt => None
# biblFull => None
# sourceDesc => None
# fileDesc => None
# head => Attribute Values
# label => br
# term => brown ink
# item =>
#
# label => ab
# term => anglicana bastarda
# item =>
#
# label => it
# term => italic
# item =>
#
# label => lc
# term => Lombard Cap
# item =>
#
# label => o[number]
# term => ornamented capital, N lines high
# item =>
#
# label => rb
# term => rubricated
# item =>
#
# label => tr
# term => touched in red
# item =>
#
# label => tx
# term => textura
# item =>
#
# label => ul
# term => underlined
# item =>
#
# label => ur
# term => underlined in red
# item =>
#
# label => gr
# term => green ink
# item =>
#
# label => bl
# term => blue ink
# item =>
#
# list => None
# p =>
#
# editorialDecl => None
# encodingDesc => None
# language => Latin
# language => French
# language => German
# langUsage => None
# hand => None
# hand => None
# hand => None
# handList => None
# term => poetry
#
# term => masculine
#
# keywords => None
# textClass => None
# profileDesc => None
# date => 199901
#
# resp => cataloger
#
# name => Jackie Shieh
#
# respStmt => None
# item => New header created
#
# change => None
# revisionDesc => None
# teiHeader => None
# front => None
# milestone => None
# note => This
# folio marker does not represent a leaf boundary at this point, but it is
# included to make it possible to display the facsimile image from this passus file.
# milestone => None
# hi => I
# hi => None
# hi => ncipit Passus Qvartus.
# hi => None
# foreign => None
# head =>
#
# hi => N
# hi => None
# hi => O
# ref => F.4.1:
# note => None
# hi => Meede
# hi => M
# expan => e
# l => None
# hi => I
# seg => -
# seg => -
# expan => e
# expan => i
# expan => h
# l => None
# hi => A
# seg => -
# expan => n
# hi => C
# expan => i
# l => None
# hi => T
# expan => e
# hi => Meed
# hi => None
# hi => M
# expan => e
# orig => a tese
# reg => at ese
# l => None
# hi => B
# expan => e
# expan => e
# seg => -
# expan => e
# l => None
# hi => W
# expan => a
# l => None
# milestone => None
# hi => &
# hi => h
# hi => h
# hi => b
# hi => w
# hi => w
# hi => ll
# hi => l
# ref => F.4.7:
# expan => us
# hi => IIII
# note => None
# l => None
# hi => I
# seg => -
# expan => e
# ref => F.4.8:
# hi => gyltis
# hi => gilt
# note => None
# l => None
# lg => None
# hi => ¶
# hi => Þ
# expan => n
# hi => C
# expan => m
# l => None
# hi => H
# hi => Meede
# hi => None
# ref => F.4.10:
# note => None
# expan => e
# l => None
# hi => &
# hi => C
# expan => con
# expan => n
# ref => F.4.11:
# note => None
# l => None
# hi => &
# expan => er
# expan => i
# expan => h
# expan => n
# hi => Meede
# hi => None
# expan => i
# expan => h
# l => None
# lg => None
# hi => ¶
# hi => S
# expan => m
# expan => a
# expan => n
# expan => e
# expan => e
# l => None
# hi => F
# hi => I
# expan => i
# expan => h
# hi => I
# hi => I
# l => None
# hi => B
# expan => e
# l => None
# hi => T
# expan => con
# expan => e
# expan => n
# hi => C
# l => None
# hi => Þ
# hi => Meede
# hi => None
# expan => o
# l => None
# hi => F
# expan => e
# hi => k
# l => None
# hi => T
# expan => e
# l => None
# hi => F
# expan => n
# sic => co
# corr => consye[n]cys
# ref => F.4.20:
# note => None
# l => None
# lg => None
# hi => ¶
# hi => Þ
# expan => n
# hi => M
# hi => Meede
# hi => None
# l => None
# hi => O
# l => None
# hi => C
# expan => i
# expan => h
# l => None
# hi => R
# expan => i
# expan => h
# ref => F.4.24:
# hi => rychesse
# hi => richesses
# note => None
# l => None
# hi => F
# expan => e
# expan => n
# expan => n
# l => None
# hi => Þ
# expan => e
# hi => L
# l => None
# hi => &
# expan => i
# expan => h
# expan => n
# hi => C
# expan => n
# expan => e
# l => None
# hi => &
# expan => n
# expan => e
# l => None
# hi => F
# expan => o
# l => None
# hi => Þ
# expan => n
# seg => -
# l => None
# hi => T
# hi => L
# l => None
# hi => F
# expan => n
# expan => ur
# l => None
# hi => S
# expan => n
# ref => F.4.33:
# hi => clerkys
# hi => leode
# note => None
# expan => a
# l => None
# hi => Þ
# expan => a
# ref => F.4.34:
# hi => Bx
# note => None
# seg => -
# seg => -
# l => None
# hi => Þ
# expan => e
# expan => a
# expan => n
# expan => e
# sic => knokke
# corr => k[l]okke
# ref => F.4.35:
# hi => knokke
# hi => klokke
# title => Piers Plowman
# note => None
# seg => -
# l => None
# lg => None
# hi => ¶
# hi => Þ
# expan => n
# expan => e
# hi => C
# expan => e
# hi => F
# l => None
# hi => T
# hi => Meede
# hi => None
# expan => a
# ref => F.4.37:
# hi => þe
# hi => þis
# note => None
# hi => M
# expan => e
# l => None
# hi => &
# l => None
# hi => Þ
# expan => n
# expan => e
# expan => n
# expan => n
# l => None
# hi => &
# hi => Fals
# hi => None
# l => None
# hi => I
# seg => -
# seg => -
# l => None
# hi => &
# expan => n
# expan => n
# expan => e
# expan => n
# l => None
# hi => A
# seg => -
# hi => C
# expan => e
# expan => con
# expan => ur
# l => None
# lg => None
# hi => ¶
# hi => Þ
# hi => Meede
# hi => None
# expan => e
# expan => a
# expan => ur
# l => None
# hi => &
# expan => e
# expan => e
# expan => e
# expan => ro
# l => None
# hi => W
# expan => e
# expan => m
# l => None
# hi => F
# expan => e
# expan => e
# l => None
# lg => None
# hi => ¶
# hi => A
# seg => -
# expan => e
# l => None
# milestone => None
# hi => W
# hi => h
# hi => h
# expan => e
# hi => l h
# l => None
# hi => W
# expan => a
# expan => er
# seg => -
# expan => e
# l => None
# hi => S
# expan => e
# seg => -
# l => None
# lg => None
# hi => ¶
# hi => Ȝ
# expan => uo
# hi => Meed
# hi => None
# sic => is
# corr => [n]is
# expan => er
# ref => F.4.52:
# hi => A
# hi => A
# lb => None
# lb => None
# lb => None
# lb => None
# lb => None
# lb => None
# lb => None
# lb => None
# lb => None
# lb => None
# lb => None
# note => None
# l => None
# hi => Þ
# expan => a
# sic => y
# corr => y [ne]
# expan => n
# l => None
# hi => &
# expan => n
# seg => -
# expan => er
# expan => er
# seg => -
# ref => F.4.54:
# hi => A
# note => None
# l => None
# hi => Þ
# expan => a
# ref => F.4.55:
# hi => ech a
# hi => euery
# note => None
# expan => e
# expan => er
# ref => F.4.55:
# note => None
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => B
# expan => ra
# l => None
# hi => &
# expan => n
# expan => n
# expan => e
# seg => -
# l => None
# hi => N
# expan => er
# ref => F.4.58:
# note => None
# l => None
# hi => F
# expan => ri
# expan => e
# expan => h
# expan => n
# expan => n
# expan => n
# l => None
# hi => B
# ref => F.4.60:
# hi => Bx
# lb => None
# lb => None
# lb => None
# lb => None
# lb => None
# note => None
# l => None
# hi => N
# hi => None
# hi => esciat sinistra   quid faciat dextera.
# hi => None
# foreign => None
# l => None
# hi => L
# expan => n
# expan => ir
# l => None
# hi => W
# expan => n
# expan => o
# expan => i
# expan => h
# expan => n
# l => None
# hi => F
# sic => dos
# corr => do[n]
# ref => F.4.64:
# note => None
# expan => er
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => M
# expan => i
# expan => h
# hi => M
# expan => a
# seg => -
# l => None
# hi => Þ
# hi => C
# expan => n
# l => None
# hi => &
# ref => F.4.67:
# note => None
# ref => F.4.67:
# hi => vpon
# hi => on
# note => None
# sic => pynyge
# corr => pyny[n]ge
# l => None
# hi => B
# expan => e
# expan => e
# l => None
# hi => F
# expan => e
# expan => n
# ref => F.4.69:
# hi => vpon
# hi => on
# note => None
# expan => a
# l => None
# hi => T
# expan => ar
# seg => -
# l => None
# hi => &
# l => None
# hi => Þ
# expan => m
# l => None
# hi => W
# expan => i
# expan => h
# expan => e
# expan => e
# l => None
# hi => F
# l => None
# hi => N
# ref => F.4.75:
# hi => ye
# note => None
# expan => er
# expan => n
# l => None
# lg => None
# hi => ¶
# hi => B
# expan => ra
# l => None
# hi => O
# expan => e
# expan => er
# l => None
# hi => O
# expan => re
# expan => i
# expan => h
# seg => -
# expan => n
# l => None
# hi => O
# expan => ra
# expan => n
# sic => mey
# corr => meyn[ten]e
# l => None
# hi => F
# ref => F.4.80:
# hi => Lord
# hi => Bx
# hi => loue
# note => None
# expan => uod
# expan => a
# expan => m
# l => None
# hi => &
# expan => m
# expan => m
# seg => -
# expan => n
# expan => n
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => K
# hi => S
# expan => n
# expan => n
# l => None
# hi => T
# seg => -
# hi => M
# hi => M
# expan => n
# expan => a
# hi => L
# l => None
# hi => &
# expan => a
# expan => er
# l => None
# hi => I
# hi => None
# expan => u
# expan => um
# expan => er
# hi => gnis deuorabit tabernac
# hi => None
# foreign => None
# ref => F.4.85:
# hi => accipiunt munera
# note => None
# l => None
# hi => A
# seg => -
# l => None
# hi => Þ
# expan => a
# l => None
# hi => Þ
# expan => a
# l => None
# hi => G
# seg => -
# seg => -
# expan => e
# ref => F.4.89:
# hi => offyȝs
# hi => offices
# note => None
# l => None
# lg => None
# hi => ¶
# hi => Þ
# hi => k
# expan => n
# expan => m
# l => None
# hi => &
# expan => er
# expan => e
# expan => i
# expan => h
# expan => er
# l => None
# milestone => None
# hi => Þ
# expan => a
# hi => b
# hi => h
# sic => None
# corr => browhtyn [hire]
# hi => b
# hi => bl
# expan => i
# expan => h
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => A
# seg => -
# l => None
# hi => &
# hi => Meed
# hi =>
# hi => M
# expan => e
# l => None
# hi => Þ
# expan => o
# expan => m
# seg => -
# expan => o
# l => None
# hi => B
# expan => o
# expan => er
# expan => o
# l => None
# hi => B
# expan => a
# expan => ra
# expan => n
# l => None
# hi => F
# expan => n
# seg => -
# expan => o
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => B
# expan => con
# hi => None
# hi => None
# expan => ra
# seg => -
# expan => n
# l => None
# hi => I
# expan => o
# expan => i
# expan => h
# expan => m
# l => None
# lg => None
# hi => ¶
# hi => Ȝ
# hi => L
# expan => uod
# hi => q
# hi => L
# expan => e
# hi => L
# seg => -
# l => None
# hi => B
# expan => ur
# sic => hange
# corr => hange [me]
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => &
# hi => Co
# hi => None
# expan => n
# seg => -
# l => None
# hi => B
# seg => -
# expan => e
# hi => k
# expan => n
# hi => C
# expan => e
# l => None
# lg => None
# hi => ¶
# hi => Þ
# expan => n
# hi => C
# hi => None
# l => None
# hi => T
# expan => e
# expan => e
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => W
# expan => o
# expan => n
# expan => m
# expan => n
# expan => uod
# expan => n
# expan => e
# seg => -
# l => None
# hi => F
# ref => F.4.108:
# note => None
# l => None
# lg => None
# hi => ¶
# hi => Q
# expan => uo
# hi => Co
# expan => n
# hi => None
# expan => ri
# seg => -
# l => None
# hi => &
# seg => -
# l => None
# hi => F
# l => None
# hi => &
# expan => n
# seg => -
# expan => e
# l => None
# hi => &
# expan => a
# expan => ri
# ref => F.4.113:
# hi => Bx
# note => None
# l => None
# hi => B
# ref => F.4.114:
# hi => Bx
# note => None
# l => None
# hi => &
# hi => L
# expan => a
# expan => e
# l => None
# hi => Ȝ
# expan => e
# ref => F.4.116:
# hi => hire
# note => None
# expan => e
# ref => F.4.116:
# hi => fayre
# hi => false
# note => None
# l => None
# hi => &
# seg => -
# seg => -
# l => None
# hi => Þ
# expan => e
# expan => m
# expan => a
# l => None
# hi => B
# seg => -
# expan => e
# expan => n
# l => None
# hi => F
# expan => e
# l => None
# hi => &
# expan => n
# l => None
# hi => S
# ref => F.2.122:
# hi => &
# hi => Bx
# hi => to
# note => None
# l => None
# hi => B
# hi => S
# hi => S
# expan => m
# expan => e
# expan => e
# expan => re
# l => None
# hi => B
# hi => S
# hi => S
# expan => n
# l => None
# hi => F
# expan => n
# expan => e
# expan => e
# l => None
# hi => &
# expan => ri
# expan => m
# l => None
# hi => &
# seg => -
# expan => e
# l => None
# hi => T
# expan => er
# expan => e
# expan => m
# l => None
# hi => &
# l => None
# hi => &
# expan => e
# expan => a
# expan => er
# l => None
# hi => T
# expan => con
# seg => -
# expan => n
# l => None
# hi => F
# hi => C
# ref => F.4.132:
# hi => klokiþ
# title => OED
# title => MED
# note => None
# expan => e
# l => None
# hi => &
# seg => -
# expan => e
# seg => -
# l => None
# milestone => None
# lg => None
# hi => ¶
# hi => S
# hi => h
# hi => M
# l => None
# hi => A
# expan => e
# hi => s
# expan => e
# expan => e
# l => None
# hi => F
# add => is
# expan => ri
# expan => i
# expan => h
# expan => ro
# l => None
# hi => F
# hi => M
# expan => er
# hi => S
# hi => None
# expan => e
# seg => -
# seg => -
# expan => n
# l => None
# hi => &
# ref => None
# lb => None
# lb => None
# note => None
# l => None
# hi => &
# expan => re
# expan => i
# expan => h
# expan => n
# l => None
# hi => &
# ref => F.4.140:
# hi => &
# hi => and lotebies
# note => None
# expan => e
# seg => -
# l => None
# hi => &
# seg => -
# expan => n
# seg => -
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => &
# expan => e
# add => is
# expan => i
# expan => h
# expan => a
# l => None
# hi => F
# expan => er
# hi => F
# hi => None
# l => None
# hi => B
# hi => I
# expan => None
# expan => i
# expan => h
# expan => e
# hi => I
# ref => F.4.144:
# hi => þe
# hi => youre
# note => None
# hi => I
# l => None
# hi => &
# seg => -
# l => None
# hi => Þ
# expan => a
# l => None
# hi => S
# seg => -
# l => None
# hi => Þ
# expan => a
# expan => n
# expan => e
# expan => a
# l => None
# hi => Ȝ
# expan => e
# l => None
# hi => F
# l => None
# hi => W
# expan => i
# expan => h
# seg => -
# expan => n
# expan => re
# l => None
# lg => None
# hi => ¶
# hi => B
# hi => B
# l => None
# hi => &
# expan => e
# expan => n
# expan => a
# l => None
# hi => F
# hi => C
# hi => C
# seg => -
# expan => e
# l => None
# hi => Þ
# expan => a
# hi => L
# expan => e
# hi => L
# expan => e
# l => None
# hi => &
# sic => alle
# corr => alle [þat]
# expan => n
# expan => e
# expan => n
# expan => m
# seg => -
# l => None
# hi => F
# expan => e
# expan => n
# ref => F.4.157:
# hi => Bx
# note => None
# l => None
# hi => T
# hi => None
# hi => H
# ref => F.4.158:
# note => None
# hi => M
# hi => None
# ref => F.4.158:
# hi => Bx
# hi => Bx
# lb => None
# lb => None
# note => None
# l => None
# hi => &
# expan => ra
# l => None
# hi => Þ
# expan => ra
# expan => e
# expan => ra
# expan => i
# expan => h
# l => None
# hi => E
# expan => o
# expan => e
# l => None
# hi => F
# hi => C
# hi => None
# expan => e
# l => None
# hi => N
# hi => L
# hi => q
# expan => uo
# expan => a
# hi => L
# expan => m
# l => None
# hi => W
# expan => yr
# expan => e
# l => None
# hi => F
# expan => a
# hi => M
# hi => M
# l => None
# hi => &
# expan => a
# ref => F.4.166:
# hi => þat
# note => None
# expan => o
# hi => C
# hi =>
# expan => i
# expan => h
# l => None
# hi => N
# expan => er
# expan => i
# expan => h
# l => None
# hi => B
# expan => o
# expan => o
# expan => e
# l => None
# hi => Þ
# expan => o
# expan => n
# l => None
# hi => &
# seg => -
# expan => ri
# ref => F.4.170:
# note => None
# expan => e
# l => None
# hi => B
# expan => o
# expan => n
# l => None
# hi => F
# expan => i
# expan => h
# l => None
# hi => &
# expan => n
# expan => e
# expan => o
# l => None
# hi => B
# expan => o
# sic => defamed
# corr => defamed [me]
# seg => -
# expan => e
# l => None
# hi => F
# expan => ru
# expan => e
# expan => er
# ref => F.4.175:
# hi => knyght
# hi => kyng
# note => None
# expan => n
# expan => ri
# expan => a
# l => None
# hi => N
# expan => o
# ref => F.4.176:
# hi => dede
# hi => Bx
# hi => kynge
# note => None
# l => None
# lg => None
# hi => ¶
# hi => F
# hi => N
# expan => n
# l => None
# milestone => None
# hi => B
# expan => o
# seg => -
# hi => l
# hi => hl
# expan => o
# hi => s
# hi => h
# ref => F.4.178:
# note => None
# l => None
# hi => F
# sic => None
# corr => Crope
# hi => C
# l => None
# hi => &
# expan => a
# expan => er
# l => None
# hi => &
# expan => o
# l => None
# hi => &
# expan => e
# expan => ir
# l => None
# lg => None
# hi => ¶
# hi => &
# expan => i
# expan => h
# seg => -
# expan => o
# expan => n
# expan => o
# ref => F.4.183:
# note => None
# l => None
# hi => &
# expan => e
# hi => C
# l => None
# hi => Þ
# expan => i
# expan => h
# hi => L
# l => None
# hi => I
# expan => n
# expan => e
# hi => M
# l => None
# hi => I
# expan => er
# expan => m
# l => None
# hi => &
# expan => m
# expan => n
# expan => e
# l => None
# lg => None
# hi => ¶
# hi => H
# expan => e
# hi => M
# expan => n
# hi => M
# l => None
# hi => I
# l => None
# hi => H
# sic => have
# corr => have [be]
# expan => a
# expan => n
# l => None
# hi => &
# expan => a
# l => None
# hi => Þ
# ref => F.4.193:
# hi => lond
# hi => Bx
# hi => blood
# note => None
# l => None
# lg => None
# hi => ¶
# hi => &
# expan => o
# hi => C
# hi => None
# expan => o
# expan => con
# expan => m
# l => None
# hi => T
# hi => L
# ref => F.4.195:
# hi => Lordchepe
# note => None
# l => None
# hi => Þ
# expan => a
# expan => a
# expan => er
# seg => -
# l => None
# hi => I
# seg => -
# expan => a
# l => None
# hi => T
# hi => M
# expan => a
# expan => m
# expan => er
# l => None
# hi => &
# expan => ir
# expan => e
# expan => m
# expan => i
# expan => h
# l => None
# hi => F
# hi => M
# hi => None
# expan => m
# seg => -
# expan => n
# seg => -
# l => None
# lg => None
# hi => ¶
# hi => E
# expan => er
# expan => e
# hi => E
# hi => L
# expan => is
# l => None
# hi => Þ
# ref => F.4.202:
# hi => ȝoomen
# hi => yonge men
# note => None
# l => None
# lg => None
# hi => ¶
# hi => Þ
# hi => P
# hi => p
# expan => re
# expan => re
# seg => -
# l => None
# hi => &
# hi => M
# hi => None
# expan => n
# seg => -
# expan => n
# l => None
# hi => &
# expan => n
# expan => e
# expan => er
# l => None
# hi => T
# hi => Meede
# expan => e
# hi => M
# expan => er
# expan => n
# seg => -
# l => None
# hi => &
# expan => e
# expan => n
# ref => F.4.207:
# hi => beggyng
# hi => biddynge
# note => None
# expan => n
# l => None
# hi => &
# hi => M
# expan => e
# expan => er
# expan => n
# expan => ro
# expan => e
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => Þ
# hi => M
# expan => n
# expan => n
# l => None
# hi => &
# expan => n
# expan => a
# ref => F.4.210:
# note => None
# l => None
# hi => P
# expan => a
# expan => re
# l => None
# hi => &
# seg => -
# expan => e
# l => None
# hi => A
# expan => er
# expan => ra
# expan => n
# expan => e
# expan => re
# l => None
# hi => &
# hi => M
# seg => -
# expan => e
# l => None
# hi => N
# expan => i
# expan => h
# expan => n
# l => None
# ref => F.4.216:
# note => None
# hi => T
# hi => None
# hi => h
# expan => e
# hi => k
# expan => con
# hi => None
# hi => None
# expan => ri
# expan => n
# l => None
# hi => N
# hi => M
# hi => M
# l => None
# lg => None
# hi => ¶
# hi => N
# expan => uod
# hi => q
# hi => c
# expan => n
# hi =>
# l => None
# hi => Þ
# expan => er
# expan => ur
# l => None
# milestone => None
# hi => Þ
# expan => a
# expan => ra
# l => None
# hi => T
# expan => a
# l => None
# hi => Þ
# hi => p
# expan => ro
# expan => et
# expan => re
# seg => -
# hi => S
# l => None
# expan => omi
# expan => ui
# expan => i
# expan => u
# expan => que
# expan => ui
# expan => ui
# expan => n
# sic => imoce
# corr => i[nn]ocens
# expan => n
# expan => us
# expan => n
# hi => D
# hi =>
# foreign => None
# ref => F.4.223:
# hi => Bx
# hi => tuo
# note => None
# l => None
# hi => H
# hi => L
# expan => n
# expan => n
# expan => i
# expan => h
# expan => n
# expan => n
# l => None
# hi => E
# ref => F.4.225:
# hi => askede
# hi => askeþ
# note => None
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => &
# hi => d
# expan => m
# seg => -
# hi => s
# expan => er
# l => None
# expan => ui
# expan => n
# expan => ur
# expan => u
# expan => er
# expan => ur
# expan => m
# hi => Q
# hi =>
# foreign => None
# l => None
# hi => Þ
# expan => a
# l => None
# hi => &
# expan => i
# expan => h
# expan => i
# expan => h
# expan => n
# l => None
# hi => &
# l => None
# hi => B
# seg => -
# expan => n
# ref => F.4.231:
# hi => Bx
# note => None
# l => None
# hi => &
# expan => a
# expan => n
# expan => i
# expan => h
# l => None
# hi => &
# expan => i
# expan => h
# seg => -
# expan => n
# hi => M
# expan => m
# ref => F.4.233:
# hi => trew
# hi => truþe
# hi => men
# note => None
# l => None
# hi => S
# expan => er
# expan => n
# expan => e
# seg => -
# l => None
# hi => O
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => s
# expan => e
# expan => on
# hi => M
# hi => None
# hi => M
# expan => a
# hi => M
# expan => ri
# l => None
# hi => T
# hi => M
# expan => n
# hi => M
# hi => None
# l => None
# hi => &
# expan => er
# hi => S
# l => None
# ref => F.4.239:
# hi => X
# note => None
# expan => uo
# expan => um
# expan => us
# expan => n
# expan => ui
# expan => n
# expan => ra
# expan => um
# expan => e
# expan => st
# expan => er
# expan => us
# hi => In q
# hi => None
# foreign => None
# l => None
# hi => H
# expan => a
# l => None
# ref => F.4.241:
# hi => Note
# note => None
# hi => H
# seg => -
# expan => er
# l => None
# hi => B
# hi => p
# expan => re
# hi => p
# expan => ar
# expan => a
# expan => re
# l => None
# hi => Þ
# hi => M
# hi => M
# hi => M
# expan => n
# l => None
# hi => &
# expan => e
# expan => e
# hi => M
# expan => n
# l => None
# expan => n
# expan => n
# hi => Ame
# hi => None
# foreign => None
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => B
# expan => a
# hi => L
# hi => l
# hi => M
# expan => ri
# l => None
# hi => I
# hi => M
# l => None
# hi => N
# hi => M
# seg => -
# l => None
# hi => I
# ref => F.4.249:
# hi => a
# hi => Permvtacioun
# note => None
# hi => P
# expan => i
# expan => n
# expan => er
# seg => -
# seg => -
# l => None
# hi => B
# expan => o
# expan => er
# expan => m
# foreign => regu
# expan => o
# hi => M
# hi => None
# l => None
# hi => W
# hi => S
# l => None
# hi => G
# hi => S
# hi => S
# hi => p
# expan => ro
# expan => et
# l => None
# hi => Þ
# expan => a
# hi => A
# hi => A
# l => None
# hi => S
# expan => a
# expan => e
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => Þ
# hi => S
# hi => S
# expan => m
# seg => -
# l => None
# hi => Þ
# expan => o
# expan => m
# ref => F.4.256:
# hi => his
# note => None
# expan => n
# l => None
# hi => W
# hi => A
# expan => i
# expan => h
# expan => n
# expan => o
# l => None
# hi => &
# expan => m
# l => None
# hi => B
# expan => m
# expan => n
# expan => i
# expan => h
# ref => F.4.259:
# note => None
# l => None
# hi => M
# seg => -
# expan => o
# expan => er
# l => None
# hi => B
# expan => e
# seg => -
# expan => er
# l => None
# milestone => None
# hi => F
# hi => M
# expan => n
# sic => þy
# corr => þyn[g]
# ref => F.4.262:
# hi => Bx
# hi => Bx
# hi => Cx
# note => None
# l => None
# hi => B
# expan => e
# expan => o
# expan => e
# l => None
# sic => /
# corr => [¶]
# hi => &
# expan => e
# l =>
# hi => &
# seg => -
# expan => m
# l => None
# hi => O
# seg => -
# expan => n
# expan => ro
# expan => et
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => Þ
# hi => S
# expan => a
# l => None
# hi => &
# expan => a
# expan => n
# ref => F.4.268:
# hi => endede
# hi => ende(n)
# note => None
# l => None
# hi => S
# hi => M
# l => None
# hi => Þ
# expan => a
# expan => m
# expan => er
# expan => er
# l => None
# hi => Þ
# expan => n
# l => None
# hi => F
# expan => n
# expan => n
# l => None
# hi => F
# expan => i
# expan => h
# expan => a
# l => None
# hi => Þ
# expan => a
# seg => -
# expan => m
# expan => e
# expan => n
# l => None
# hi => I
# expan => uod
# hi => q
# hi => c
# expan => n
# hi => None
# l => None
# hi => Þ
# expan => a
# hi => r
# expan => n
# hi => None
# l => None
# hi => &
# hi => A
# expan => e
# expan => m
# l => None
# hi => F
# hi => S
# sic => fle
# corr => [s]le
# expan => m
# l => None
# hi => &
# expan => aui
# hi => d
# expan => n
# expan => m
# l => None
# hi => &
# expan => ri
# ref => F.4.280:
# hi => B
# note => None
# l => None
# hi => S
# expan => e
# expan => er
# ref => F.4.281:
# hi => he
# hi => she
# note => None
# l => None
# hi => B
# hi => love
# hi => lowenesse
# hi => lewte
# seg => -
# l => None
# hi => Þ
# expan => e
# hi => M
# expan => ri
# hi => M
# hi => t
# hi => None
# l => None
# hi => &
# expan => re
# seg => -
# expan => n
# hi => t
# expan => re
# hi => None
# seg => -
# expan => n
# expan => e
# l => None
# hi => L
# hi => None
# expan => m
# l => None
# hi => S
# expan => n
# expan => er
# l => None
# hi => N
# expan => e
# expan => n
# expan => e
# l => None
# hi => B
# hi => M
# hi => M
# expan => n
# expan => is
# l => None
# hi => &
# hi => L
# hi => L
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => B
# hi => l
# hi => None
# expan => n
# seg => -
# expan => e
# ref => None
# expan => ota
# hi => n
# note => None
# l => None
# hi => &
# seg => -
# l => None
# hi => &
# ref => F.4.292:
# hi => a
# hi => pees
# note => None
# seg => -
# expan => n
# expan => ar
# l => None
# hi => Þ
# expan => a
# expan => e
# expan => n
# expan => e
# l => None
# hi => Þ
# expan => a
# hi => M
# hi => M
# expan => n
# seg => -
# l => None
# hi => &
# expan => a
# expan => n
# expan => e
# expan => e
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => &
# expan => e
# expan => a
# expan => n
# expan => e
# ref => F.4.296:
# note => None
# seg => -
# l => None
# hi => E
# l => None
# hi => S
# expan => e
# expan => m
# l => None
# hi => I
# seg => -
# expan => n
# seg => -
# l => None
# milestone => None
# hi => E
# hi => None
# expan => n
# expan => er
# hi => t conflabu
# hi => None
# foreign => None
# l => None
# hi => E
# expan => i
# expan => h
# l => None
# hi => O
# expan => n
# expan => n
# ref => F.4.302:
# hi => lese
# hi => spille
# note => None
# expan => m
# seg => -
# expan => i
# expan => h
# l => None
# lg => None
# hi => ¶
# hi => P
# expan => ar
# expan => i
# expan => h
# hi => P
# foreign => None
# expan => e
# l => None
# hi => &
# expan => er
# l => None
# hi => H
# l => None
# hi => F
# seg => -
# expan => m
# expan => er
# l => None
# lg => None
# hi => ¶
# hi => S
# expan => ir
# expan => n
# l => None
# hi => O
# expan => n
# expan => e
# expan => m
# l => None
# hi => N
# expan => e
# l => None
# hi => B
# expan => er
# expan => a
# l => None
# hi => E
# expan => i
# expan => h
# expan => er
# expan => i
# expan => h
# expan => er
# expan => e
# seg => -
# l => None
# lg => None
# hi => ¶
# hi => B
# expan => n
# l => None
# hi => A
# expan => e
# expan => e
# expan => n
# l => None
# hi => Þ
# expan => n
# expan => re
# expan => n
# expan => n
# expan => a
# expan => n
# ref => F.4.314:
# hi => Bx
# note => None
# l => None
# lg => None
# hi => ¶
# hi => N
# expan => n
# expan => e
# expan => n
# expan => e
# l => None
# expan => a
# ref => F.4.316:
# hi => smythie
# hi => smyteth
# hi => smyþeþ
# note => None
# seg => -
# l => & what smeþ þ
# hi => N
# hi => None
# expan => i
# expan => n
# expan => n
# expan => ra
# expan => n
# expan => m
# expan => m
# hi => on leuab
# hi => None
# foreign => None
# l => None
# hi => F
# hi => None
# l => & er þis
# ref => F.4.319:
# note => None
# expan => n
# l => None
# hi => M
# hi => M
# hi => I
# ref => F.4.320:
# hi => to
# hi => Iewis
# note => None
# expan => ur
# l => & þe
# expan => er
# ref => F.4.321:
# note => None
# expan => e
# expan => n
# expan => or
# hi => Gl
# hi => None
# foreign => None
# l => & þe sarsynes for þe syghte þ
# ref => F.4.322:
# hi => B
# hi => For
# note => None
# hi => M
# hi => M
# seg => -
# expan => e
# ref => F.4.322:
# hi => B
# hi => þey
# note => None
# expan => a
# l => Þorghȝ
# hi => F
# expan => m
# expan => n
# expan => ab
# expan => ua
# expan => u
# hi => melius est bonu
# hi => None
# foreign => None
# l => None
# lg => None
# hi => ¶
# hi => Þ
# l => None
# expan => uod
# hi => Q
# l => None
# hi => N
# hi => s
# expan => n
# l => None
# hi => O
# expan => a
# l => None
# hi => &
# expan => er
# l => None
# hi => H
# hi => None
# expan => m
# expan => er
# hi => onore
# hi => None
# foreign => None
# l => None
# lg => None
# hi => ¶
# hi => I
# hi => L
# expan => uod
# hi => q
# hi => c
# expan => n
# expan => a
# expan => n
# l => None
# hi => B
# expan => o
# hi => N
# expan => n
# ref => F.4.331:
# hi => Nunne
# note => None
# hi => L
# expan => a
# expan => n
# l => None
# hi => I
# expan => m
# hi => omnia aute
# hi => None
# foreign => None
# expan => a
# expan => e
# l => None
# hi => F
# expan => a
# hi => L
# expan => e
# l => None
# hi => H
# expan => ir
# seg => -
# l => None
# hi => S
# expan => is
# expan => er
# l => None
# hi => Þ
# expan => a
# expan => uo
# expan => m
# expan => st
# foreign => q
# hi => None
# hi => None
# expan => a
# l => None
# hi => &
# hi => M
# l => None
# hi => O
# expan => a
# expan => n
# expan => n
# expan => e
# l => None
# hi => B
# expan => a
# ref => F.4.339:
# hi => Bx
# note => None
# l => None
# hi => B
# expan => a
# expan => ur
# ref => F.4.340:
# hi => Bx
# note => None
# l => None
# hi => &
# hi => S
# expan => a
# expan => e
# expan => h
# l => None
# milestone => None
# hi => A
# hi => l
# hi => l
# expan => a
# hi => l
# expan => a
# ref => F.4.342:
# hi => Bx
# lb => None
# lb => None
# foreign => Animam autem aufert accipientium &c.
# lb => None
# note => None
# l => None
# hi => &
# ref => F.4.343:
# hi => me
# hi => Mede
# note => None
# l => None
# hi => Ȝ
# expan => a
# l => None
# milestone => None
# hi => N
# hi => None
# hi => O
# expan => er
# l => None
# hi => Ȝ
# seg => -
# expan => n
# l => None
# hi => K
# expan => e
# expan => uod
# hi => q
# hi => þ
# hi => kyng
# expan => o
# l => None
# hi => N
# expan => ri
# expan => uod
# hi => q
# expan => n
# hi => Co
# hi => None
# ref => F.4.348:
# hi => honge
# hi => Bx
# hi => congeye
# note => None
# l => None
# hi => B
# expan => n
# hi => Resou
# expan => er
# expan => e
# expan => e
# l => None
# hi => Þ
# expan => uod
# space => None
# ref => F.4.350:
# hi => kyng
# note => None
# hi => Consyence
# expan => e
# l => None
# hi => R
# seg => -
# hi => &
# hi => R
# expan => n
# hi => None
# expan => a
# expan => o
# l => None
# hi => &
# expan => m
# expan => a
# expan => n
# expan => n
# expan => e
# l => None
# hi => F
# ref => F.4.353:
# hi => B
# hi => 23
# hi => 2
# hi => A
# hi => C
# note => None
# l => None
# hi => &
# seg => -
# expan => e
# expan => i
# expan => h
# expan => n
# hi => Co
# hi => None
# expan => ri
# l => None
# hi => H
# expan => o
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => I
# expan => e
# expan => a
# l => None
# hi => &
# expan => n
# hi => resou
# hi =>
# expan => e
# l => None
# hi => &
# expan => m
# hi => kyng
# l => None
# lg => None
# hi => ¶
# hi => I
# expan => e
# seg => -
# expan => uod
# hi => q
# expan => n
# hi => Resou
# hi => None
# expan => er
# l => None
# hi => A
# seg => -
# expan => n
# hi => Ca
# expan => n
# expan => ur
# l => None
# hi => &
# hi => To
# hi =>
# hi => trewe
# expan => n
# hi => tu
# expan => a
# l => None
# hi => N
# hi => l
# hi => L
# expan => m
# expan => er
# l => None
# hi => H
# expan => e
# hi => suffr
# hi => None
# l => None
# hi => &
# expan => m
# expan => i
# expan => h
# expan => a
# expan => i
# expan => h
# l => None
# hi => &
# expan => m
# l => None
# hi => F
# hi => w
# hi => h
# hi => trewþ
# hi => None
# ref => F.4.366:
# hi => to trewþe
# hi => Bx
# hi => twies
# note => None
# expan => e
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => Þ
# hi => Consience
# hi => None
# l => None
# hi => &
# expan => n
# hi => Resou
# hi => None
# expan => i
# expan => h
# expan => m
# seg => -
# l => None
# hi => Meed
# hi => None
# hi => M
# ref => F.4.369:
# note => None
# l => Whiche Maystryes on erthe /
# lg => None
# hi => ¶
# hi => A
# seg => -
# expan => n
# hi => w
# hi => None
# hi => wyȝsdom
# hi => None
# hi => watte witty
# l => None
# hi => F
# expan => n
# l => None
# hi => I
# hi => C
# hi => C
# expan => e
# l => None
# hi => F
# expan => n
# expan => a
# expan => m
# l => None
# hi => F
# expan => e
# expan => m
# expan => ra
# l => None
# hi => &
# hi => Consyence
# hi => None
# expan => a
# l => None
# hi => &
# expan => n
# hi => resou
# hi => None
# l => None
# hi => F
# expan => e
# expan => e
# expan => e
# expan => i
# expan => h
# hi => Meede
# hi => None
# l => None
# hi => &
# expan => n
# expan => er
# expan => er
# l => None
# hi => &
# expan => e
# expan => a
# hi => l
# hi => v
# hi => lewt
# expan => e
# l => None
# hi => F
# ref => F.4.380:
# note => None
# l => None
# hi => C
# hi => None
# expan => ri
# expan => i
# expan => n
# expan => n
# expan => um
# hi => ont
# hi => None
# foreign => None
# l => None
# hi => N
# hi => None
# expan => te
# expan => u
# sic => occ
# corr => o[c]ulos
# expan => um
# hi => on est timor dei an
# hi => None
# foreign => None
# l => None
# milestone => None
# hi => F
# expan => e
# sic => dosey
# corr => dosey[n]
# l => None
# hi => O
# hi => C
# l => None
# hi => Þ
# expan => e
# l => None
# hi => Þ
# expan => e
# ref => F.4.386:
# hi => Reson
# hi => lete
# note => None
# expan => n
# seg => -
# l => None
# hi => F
# hi => C
# expan => n
# expan => ri
# expan => ro
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => Þ
# add => reson
# ref => F.4.388:
# note => None
# l => None
# hi => A
# hi => C
# hi => None
# expan => m
# l => None
# lg => None
# hi => ¶
# hi => Þ
# hi => C
# expan => n
# seg => -
# expan => n
# expan => n
# l => None
# hi => &
# seg => -
# expan => m
# expan => m
# l => None
# hi => &
# seg => -
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => &
# expan => n
# hi => p
# hi => None
# expan => a
# expan => ar
# expan => n
# l => None
# hi => H
# hi => W
# hi => None
# seg => -
# expan => n
# seg => -
# l => None
# hi => &
# hi => R
# hi => R
# hi => d
# expan => er
# l => None
# hi => &
# seg => -
# hi => M
# expan => e
# expan => e
# hi => M
# expan => e
# expan => e
# l => None
# hi => &
# expan => n
# expan => n
# l => None
# hi => &
# l => None
# hi => H
# expan => m
# seg => -
# expan => n
# expan => er
# l => None
# hi => N
# expan => er
# expan => e
# ref => F.4.400:
# hi => nowht
# hi => ouȝt
# note => None
# l => None
# hi => A
# expan => n
# expan => n
# expan => e
# sic => moþer
# corr => m[u]rþere
# expan => n
# ref => F.4.401:
# hi => heuuys
# hi => hewen
# hi => moþere
# note => None
# l => None
# hi => &
# sic => None
# hi => &
# corr => None
# seg => -
# expan => n
# l => None
# hi => H
# seg => -
# l => None
# hi => &
# l => None
# hi => &
# expan => er
# l => None
# hi => I
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => Þ
# expan => e
# hi => C
# expan => n
# hi => None
# expan => m
# l => None
# hi => Þ
# expan => a
# ref => F.4.408:
# hi => muche
# note => None
# l => None
# lg => None
# hi => ¶
# hi => Þ
# hi => wrong
# hi => None
# seg => -
# hi => w
# hi => None
# l => None
# hi => T
# expan => i
# expan => h
# expan => ro
# l => None
# hi => &
# sic => hadde
# corr => hadde [y]
# l => None
# hi => Þ
# expan => i
# expan => h
# expan => m
# ref => F.4.412:
# hi => Bx
# lb => None
# lb => None
# lb => None
# lb => None
# note => None
# l => None
# hi => I
# expan => n
# seg => -
# expan => o
# l => None
# hi => F
# l => None
# hi => F
# expan => n
# expan => ra
# l => None
# sic => /
# corr => [¶]
# hi => Þ
# hi => wro
# hi => None
# hi => w
# hi => None
# l => None
# hi => T
# expan => i
# expan => h
# seg => -
# l => None
# hi => Þ
# hi => w
# hi => None
# hi => w
# hi => None
# seg => -
# expan => n
# seg => -
# l => None
# hi => &
# hi => Meed
# hi => None
# hi => M
# l => None
# lg => None
# hi => ¶
# hi => P
# hi => None
# l => None
# hi => W
# expan => i
# expan => h
# seg => -
# expan => n
# l => None
# hi => B
# hi => Con
# hi =>
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => &
# expan => er
# hi => w
# hi => None
# hi => w
# hi => None
# expan => n
# seg => -
# expan => n
# l => None
# hi => T
# seg => -
# hi => k
# expan => i
# expan => h
# l => None
# milestone => None
# hi => ¶
# hi => Þ
# hi => k
# hi => b
# hi => C
# hi => b
# hi => h
# hi => C
# hi => b
# l => None
# hi => Þ
# expan => a
# expan => n
# hi => wro
# l => None
# hi => A
# seg => -
# expan => n
# hi => C
# expan => n
# expan => m
# add => in
# ref => F.4.427:
# hi => in
# note => None
# l => None
# hi => &
# expan => er
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => A
# expan => uod
# hi => q
# hi => Wi
# hi => dom
# hi => None
# l => None
# hi => B
# seg => -
# expan => n
# hi => M
# expan => ri
# expan => m
# l => None
# hi => &
# expan => m
# l => None
# hi => &
# seg => -
# expan => n
# expan => a
# seg => -
# expan => er
# l => None
# hi => ¶
# hi => A
# seg => -
# expan => n
# hi => w
# hi => None
# seg => -
# expan => er
# expan => i
# expan => h
# expan => n
# l => None
# hi => Þ
# expan => a
# expan => e
# expan => e
# expan => a
# l => None
# hi => Þ
# seg => -
# expan => er
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => &
# expan => n
# hi => Meede
# hi => None
# hi => M
# expan => e
# expan => er
# seg => -
# l => None
# hi => &
# expan => ro
# expan => re
# l => None
# hi => H
# expan => uod
# hi => q
# hi => s
# seg => -
# expan => n
# l => None
# hi => F
# expan => e
# hi => w
# expan => e
# l => None
# hi => ¶
# hi => Þ
# hi => P
# expan => ra
# l => None
# hi => H
# expan => er
# expan => a
# expan => a
# l => None
# hi => F
# expan => m
# l => None
# hi => &
# seg => -
# expan => m
# expan => i
# expan => h
# l => None
# hi => S
# seg => -
# expan => er
# expan => e
# l => None
# hi => F
# hi => Meed
# hi => None
# expan => n
# seg => -
# expan => n
# expan => e
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => N
# expan => uod
# l => None
# hi => W
# hi => None
# expan => e
# expan => e
# l => None
# hi => F
# seg => -
# l => None
# hi => &
# expan => e
# l => None
# hi => B
# hi => r
# expan => n
# hi => None
# expan => m
# l => None
# hi => &
# expan => a
# expan => m
# l => None
# lg => None
# hi => ¶
# hi => F
# hi => r
# expan => n
# hi => None
# expan => a
# l => None
# hi => Þ
# expan => a
# hi => c
# expan => n
# hi => None
# expan => er
# l => None
# hi => Þ
# expan => a
# hi => Meede
# hi => None
# hi => p
# expan => ar
# expan => ur
# ref => None
# hi => Bx
# hi => Bx
# lb => None
# lb => None
# lb => None
# note => None
# hi => re
# expan => n
# hi =>
# seg => -
# l => None
# lg => None
# sic => /
# corr => [¶]
# hi => N
# expan => uod
# hi => q
# hi => R
# expan => n
# hi => None
# expan => ra
# l => None
# hi => T
# hi => L
# hi => L
# l => None
# hi => &
# expan => ri
# l => None
# hi => &
# hi => P
# expan => e
# expan => e
# l => None
# hi => &
# hi => C
# hi => C
# sic =>
# corr => Chy[l]d[r]ene Chyr[y]synge
# expan => i
# expan => h
# l => None
# hi => &
# l => None
# hi => &
# hi => C
# sic => Po
# corr => Po[re & fede]
# ref => F.4.461:
# hi => Po
# hi => Bx
# hi => Bx
# note => None
# l => None
# hi => &
# expan => n
# expan => e
# expan => e
# l => None
# hi => A
# hi => s
# expan => n
# hi => B
# expan => m
# hi => B
# hi => F
# l => None
# hi => &
# hi => p
# expan => re
# hi => p
# expan => re
# seg => -
# l => None
# milestone => None
# hi => &
# hi => l
# hi => k
# hi => l
# hi => b
# expan => n
# expan => ro
# l => None
# hi => &
# hi => B
# expan => e
# expan => e
# l => None
# hi => &
# expan => e
# expan => is
# expan => e
# l => None
# hi => &
# hi => S
# expan => n
# hi => I
# expan => e
# seg => -
# l => None
# hi => Þ
# expan => a
# hi => G
# l => None
# hi => &
# seg => -
# l => None
# hi => B
# expan => er
# expan => a
# expan => e
# expan => h
# l => None
# hi => N
# expan => ir
# expan => ra
# expan => ra
# expan => ir
# l => None
# hi => V
# expan => e
# expan => er
# l => None
# hi => B
# expan => ar
# expan => n
# expan => n
# expan => er
# expan => i
# expan => h
# expan => ri
# l => None
# hi => E
# hi => p
# expan => ro
# expan => n
# l => None
# lg => None
# hi => ¶
# hi => &
# expan => uod
# hi => q
# ref => F.4.476:
# expan => uod
# note => None
# hi => R
# hi => None
# sic => rewþe
# corr => [no] rewþe
# l => None
# hi => W
# expan => e
# hi => M
# hi => M
# expan => ri
# expan => e
# l => None
# hi => F
# expan => ir
# l => None
# hi => I
# expan => n
# seg => -
# expan => uod
# hi => q
# hi => h
# l => None
# hi => Þ
# expan => a
# expan => e
# hi => k
# expan => i
# expan => h
# l => None
# hi => S
# expan => er
# expan => n
# expan => a
# l => None
# hi => B
# expan => n
# expan => er
# l => None
# hi => N
# expan => ra
# l => None
# hi => N
# expan => er
# l => None
# hi => F
# expan => m
# expan => m
# hi => nullu
# hi => None
# foreign => None
# expan => i
# expan => h
# expan => m
# hi => inpunitu
# hi => None
# foreign => None
# l => None
# hi => &
# expan => m
# hi => nullum bonu
# hi => None
# foreign => None
# expan => m
# hi => irremuneratu
# hi => None
# foreign => None
# l => None
# hi => L
# expan => e
# expan => n
# hi => s
# expan => e
# hi => k
# l => None
# hi => &
# orig => hewerke
# reg => he werke
# l => None
# hi => Þ
# expan => a
# hi => L
# l => None
# hi => L
# expan => n
# hi => L
# l => &
# hi => ¶
# hi => A
# expan => n
# hi => C
# expan => n
# seg => -
# l => None
# hi => T
# sic => clawse
# corr => [þis] clawse
# expan => ro
# l => None
# hi => B
# expan => n
# expan => n
# l => None
# hi => F
# hi => Meede
# hi => M
# expan => e
# expan => n
# l => None
# hi => &
# expan => e
# expan => n
# l => None
# lg => None
# hi => ¶
# hi => S
# hi => W
# hi => None
# hi => Wyȝsdom
# seg => -
# hi => Meede
# l => None
# hi => &
# expan => e
# hi => M
# expan => e
# expan => n
# seg => -
# l => None
# hi => I
# expan => uod
# hi => q
# expan => a
# l => None
# hi => ¶
# hi => &
# expan => n
# hi => R
# hi => None
# expan => a
# hi => re
# expan => n
# hi => ou
# hi =>
# l => None
# hi => &
# hi => w
# hi => None
# seg => -
# expan => er
# expan => i
# expan => h
# l => None
# hi => A
# seg => -
# expan => n
# expan => e
# expan => e
# l => None
# hi => Þ
# hi => Meekness
# hi => None
# hi => M
# expan => er
# hi => meede
# hi => None
# expan => n
# expan => e
# l => None
# hi => Þ
# hi => Love
# hi => None
# expan => e
# hi => L
# hi => None
# l => None
# hi => &
# l => None
# milestone => None
# hi => Wh
# hi => l
# hi => M
# hi => None
# ref => F.4.505:
# hi => V
# note => None
# l => None
# hi => B
# expan => e
# l => None
# lg => None
# hi => ¶
# hi => Þ
# hi => Meed
# hi => None
# hi => M
# expan => ur
# l => None
# hi => F
# expan => e
# ref => F.4.508:
# note => None
# expan => e
# expan => e
# sic => as
# corr => a[n]
# l => None
# lg => None
# hi => ¶
# hi => B
# hi => S
# hi => s
# expan => m
# l => None
# hi => &
# hi => s
# expan => e
# l => None
# hi => A
# expan => uod
# hi => y q
# l => None
# hi => &
# expan => er
# l => None
# lg => None
# hi => ¶
# hi => Þ
# expan => e
# expan => n
# l => None
# hi => &
# expan => a
# expan => n
# l => None
# hi => Þ
# hi => Moode
# seg => -
# hi => L
# hi => None
# ref => F.4.515:
# note => None
# hi => k
# l => None
# hi => &
# expan => i
# expan => h
# hi => L
# hi => Meed
# hi => None
# expan => m
# seg => -
# l => None
# hi => &
# expan => e
# expan => e
# hi => L
# l => None
# hi => F
# hi => Meed
# hi => None
# expan => er
# seg => -
# hi => M
# expan => ri
# hi => L
# hi => M
# expan => re
# l => None
# lg => None
# hi => ¶
# hi => B
# hi => r
# expan => n
# hi => None
# expan => i
# expan => h
# l => None
# hi => &
# l => None
# hi => M
# sic => None
# hi => M
# corr => None
# expan => n
# expan => ri
# hi => M
# l => None
# hi => I
# expan => e
# hi => l
# hi => None
# expan => ur
# expan => n
# l => None
# hi => &
# expan => e
# l => None
# hi => ¶
# hi => S
# expan => uod
# hi => q
# hi => C
# hi =>
# hi => k
# expan => n
# l => None
# hi => I
# expan => n
# seg => -
# l => None
# hi => A
# expan => e
# expan => e
# l => None
# lg => None
# hi => ¶
# hi => B
# expan => m
# expan => a
# expan => uod
# hi => q
# expan => n
# hi => Resou
# hi => None
# expan => n
# l => None
# hi => B
# expan => us
# expan => e
# l => None
# hi => I
# expan => e
# hi => B
# expan => m
# orig => tome
# reg => to me
# l => None
# lg => None
# hi => ¶
# hi => Þ
# expan => uod
# hi => k
# hi => L
# l => None
# hi => T
# expan => n
# expan => n
# expan => e
# expan => a
# seg => -
# expan => n
# hi => C
# expan => is
# l => None
# hi => B
# expan => n
# hi => resou
# hi =>
# expan => o
# orig => frome
# reg => fro me
# l => None
# hi => F
# l => None
# lg => None
# hi => ¶
# hi => I
# expan => uod
# expan => n
# expan => i
# expan => h
# expan => er
# ref => F.4.534:
# hi => Bx
# note => None
# l => None
# hi => &
# expan => uod
# hi => q
# hi => k
# seg => -
# expan => o
# l => None
# hi => A
# expan => e
# seg => -
# l => None
# milestone => None
# sic => /
# corr => [¶]
# hi => T
# expan => i
# expan => h
# expan => n
# l => None
# hi => T
# hi => M
# hi => M
# l => None
# lg => None
# hi => E
# hi => None
# hi => xplicit
# hi => P
# hi => assus
# hi => Q
# hi => uartus.
# foreign => None
# trailer =>
#
# div1 => None
# body => None
# text => None
# TEI.2 => None
# []

# %% [markdown]
# ---
#
# ## Bibliography

# %% [markdown]
# All work is adapted or taken from:
# - Driscoll, Mike. (2013, April). Python 101 – Intro to XML Parsing with ElementTree. Retrieved from https://www.blog.pythonlibrary.org/2013/04/30/python-101-intro-to-xml-parsing-with-elementtree/
#
# - Driscoll, Mike. (2010, November). Python: Parsing XML with lxml. Retrieved from https://www.blog.pythonlibrary.org/2010/11/20/python-parsing-xml-with-lxml/

# %% [markdown]
# ---
# Notebook developed by: Tejas Priyadarshan
#
# Data Science Modules: http://data.berkeley.edu/education/modules
